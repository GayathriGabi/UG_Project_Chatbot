# %% [markdown]
# # CHATBOT FOR COLLEGE CONTENT RESPONSE USING NLP

# %% [markdown]
# History of chatbots dates back to 1966 when a computer program called ELIZA was invented by Weizenbaum. It imitated the language of a psychotherapist from only 200 lines of code. You can still converse with it here: Eliza.
#
# On similar lines let's create a very basic chatbot utlising the Python's NLTK library.It's a very simple bot with hardly any cognitive skills,but still a good way to get into NLP and get to know about chatbots.
#
# # NLP
# NLP is a way for computers to analyze, understand, and derive meaning from human language in a smart and useful way. By utilizing NLP, developers can organize and structure knowledge to perform tasks such as automatic summarization, translation, named entity recognition, relationship extraction, sentiment analysis, speech recognition, and topic segmentation.

# %% [markdown]
# # Import necessary libraries

# %%
import io
import random
import string # to process standard python strings
import warnings
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Downloading and installing NLTK
# NLTK(Natural Language Toolkit) is a leading platform for building Python programs to work with human language data. It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along with a suite of text processing libraries for classification, tokenization, stemming, tagging, parsing, and semantic reasoning, wrappers for industrial-strength NLP libraries.
#
# Natural Language Processing with Python provides a practical introduction to programming for language processing.

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\gayathri\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\gayathri\anaconda3\lib\site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: joblib in c:\users\gayathri\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: tqdm in c:\users\gayathri\anaconda3\lib\site-packages (from nltk) (4.64.0)
# Requirement already satisfied: click in c:\users\gayathri\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: colorama in c:\users\gayathri\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

path = r'C:\Users\GAYATHRI\OneDrive\Documents\SRET-I YR- MSC\TERM III\Machine Learning\FinalProject'

for filename in os.listdir(path):
    filen = os.path.join(path, filename)
    print(filen)

    with open(filen, 'r', encoding='utf-8') as f:
        content = f.read()
        print(content)
# Out:
# C:\Users\GAYATHRI\OneDrive\Documents\SRET-I YR- MSC\TERM III\Machine Learning\FinalProject\Chatbot.txt
# A chatbot (also known as a talkbot, chatterbot, Bot, IM bot, interactive agent, or Artificial Conversational Entity) is a computer program or an artificial intelligence which conducts a conversation via auditory or textual methods. Such programs are often designed to convincingly simulate how a human would behave as a conversational partner, thereby passing the Turing test. Chatbots are typically used in dialog systems for various practical purposes including customer service or information acquisition. Some chatterbots use sophisticated natural language processing systems, but many simpler systems scan for keywords within the input, then pull a reply with the most matching keywords, or the most similar wording pattern, from a database.
#
# The term "ChatterBot" was originally coined by Michael Mauldin (creator of the first Verbot, Julia) in 1994 to describe these conversational programs.Today, most chatbots are either accessed via virtual assistants such as Google Assistant and Amazon Alexa, via messaging apps such as Facebook Messenger or WeChat, or via individual organizations' apps and websites. Chatbots can be classified into usage categories such as conversational commerce (e-commerce via chat), analytics, communication, customer support, design, developer tools, education, entertainment, finance, food, games, health, HR, marketing, news, personal, productivity, shopping, social, sports, travel and utilities.
# Background
# In 1950, Alan Turing's famous article "Computing Machinery and Intelligence" was published, which proposed what is now called the Turing test as a criterion of intelligence. This criterion depends on the ability of a computer program to impersonate a human in a real-time written conversation with a human judge, sufficiently well that the judge is unable to distinguish reliably—on the basis of the conversational content alone—between the program and a real human. The notoriety of Turing's proposed test stimulated great interest in Joseph Weizenbaum's program ELIZA, published in 1966, which seemed to be able to fool users into believing that they were conversing with a real human. However Weizenbaum himself did not claim that ELIZA was genuinely intelligent, and the Introduction to his paper presented it more as a debunking exercise:
#
# [In] artificial intelligence ... machines are made to behave in wondrous ways, often sufficient to dazzle even the most experienced observer. But once a particular program is unmasked, once its inner workings are explained ... its magic crumbles away; it stands revealed as a mere collection of procedures ... The observer says to himself "I could have written that". With that thought he moves the program in question from the shelf marked "intelligent", to that reserved for curios ... The object of this paper is to cause just such a re-evaluation of the program about to be "explained". Few programs ever needed it more.
#
# ELIZA's key method of operation (copied by chatbot designers ever since) involves the recognition of cue words or phrases in the input, and the output of corresponding pre-prepared or pre-programmed responses that can move the conversation forward in an apparently meaningful way (e.g. by responding to any input that contains the word 'MOTHER' with 'TELL ME MORE ABOUT YOUR FAMILY').Thus an illusion of understanding is generated, even though the processing involved has been merely superficial. ELIZA showed that such an illusion is surprisingly easy to generate, because human judges are so ready to give the benefit of the doubt when conversational responses are capable of being interpreted as "intelligent".
#
# Interface designers have come to appreciate that humans' readiness to interpret computer output as genuinely conversational—even when it is actually based on rather simple pattern-matching—can be exploited for useful purposes. Most people prefer to engage with programs that are human-like, and this gives chatbot-style techniques a potentially useful role in interactive systems that need to elicit information from users, as long as that information is relatively straightforward and falls into predictable categories. Thus, for example, online help systems can usefully employ chatbot techniques to identify the area of help that users require, potentially providing a "friendlier" interface than a more formal search or menu system. This sort of usage holds the prospect of moving chatbot technology from Weizenbaum's "shelf ... reserved for curios" to that marked "genuinely useful computational methods".
#
# Development
# The classic historic early chatbots are ELIZA (1966) and PARRY (1972).More recent notable programs include A.L.I.C.E., Jabberwacky and D.U.D.E (Agence Nationale de la Recherche and CNRS 2006). While ELIZA and PARRY were used exclusively to simulate typed conversation, many chatbots now include functional features such as games and web searching abilities. In 1984, a book called The Policeman's Beard is Half Constructed was published, allegedly written by the chatbot Racter (though the program as released would not have been capable of doing so).
#
# One pertinent field of AI research is natural language processing. Usually, weak AI fields employ specialized software or programming languages created specifically for the narrow function required. For example, A.L.I.C.E. uses a markup language called AIML, which is specific to its function as a conversational agent, and has since been adopted by various other developers of, so called, Alicebots. Nevertheless, A.L.I.C.E. is still purely based on pattern matching techniques without any reasoning capabilities, the same technique ELIZA was using back in 1966. This is not strong AI, which would require sapience and logical reasoning abilities.
#
# Jabberwacky learns new responses and context based on real-time user interactions, rather than being driven from a static database. Some more recent chatbots also combine real-time learning with evolutionary algorithms that optimise their ability to communicate based on each conversation held. Still, there is currently no general purpose conversational artificial intelligence, and some software developers focus on the practical aspect, information retrieval.
#
# Chatbot competitions focus on the Turing test or more specific goals. Two such annual contests are the Loebner Prize and The Chatterbox Challenge (offline since 2015, materials can still be found from web archives).
#
# According to Forrester (2015), AI will replace 16 percent of American jobs by the end of the decade.Chatbots have been used in applications such as customer service, sales and product education. However, a study conducted by Narrative Science in 2015 found that 80 percent of their respondents believe AI improves worker performance and creates jobs.[citation needed]
#
# Application
# See also: Virtual assistant
#
# Aeromexico airline chatbot running on Facebook Messenger, March 2018
# Messaging apps
# Many companies' chatbots run on messaging apps like Facebook Messenger (since 2016), WeChat (since 2013),WhatsApp, LiveChat, Kik, Slack, Line, Telegram, or simply via SMS. They are used for B2C customer service, sales and marketing.
#
# In 2016, Facebook Messenger allowed developers to place chatbots on their platform. There were 30,000 bots created for Messenger in the first six months, rising to 100,000 by September 2017.
#
# Since September 2017, this has also been as part of a pilot program on WhatsApp. Airlines KLM and Aeroméxico both announced their participation in the testing;both airlines had previously launched customer services on the Facebook Messenger platform.
#
# The bots usually appear as one of the user's contacts, but can sometimes act as participants in a group chat.
#
# Many banks and insurers, media and e-commerce companies, airlines and hotel chains, retailers, health care providers, government entities and restaurant chains have used chatbots to answer simple questions, increase customer engagement,for promotion, and to offer additional ways to order from them.
#
# A 2017 study showed 4% of companies used chatbots.According to a 2016 study, 80% of businesses said they intended to have one by 2020.
#
# As part of company apps and websites
# Previous generations of chatbots were present on company websites, e.g. Ask Jenn from Alaska Airlines which debuted in 2008 or Expedia's virtual customer service agent which launched in 2011.The newer generation of chatbots includes IBM Watson-powered "Rocky", introduced in February 2017 by the New York City-based e-commerce company Rare Carat to provide information to prospective diamond buyers.
#
# Company internal platforms
# Other companies explore ways they can use chatbots internally, for example for Customer Support, Human Resources, or even in Internet-of-Things (IoT) projects. Overstock.com, for one, has reportedly launched a chatbot named Mila to automate certain simple yet time-consuming processes when requesting for a sick leave.Other large companies such as Lloyds Banking Group, Royal Bank of Scotland, Renault and Citroën are now using automated online assistants instead of call centres with humans to provide a first point of contact. A SaaS chatbot business ecosystem has been steadily growing since the F8 Conference when Zuckerberg unveiled that Messenger would allow chatbots into the app.
#
# Toys
# Chatbots have also been incorporated into devices not primarily meant for computing such as toys.
#
# Hello Barbie is an Internet-connected version of the doll that uses a chatbot provided by the company ToyTalk,which previously used the chatbot for a range of smartphone-based characters for children.These characters' behaviors are constrained by a set of rules that in effect emulate a particular character and produce a storyline.
#
# IBM's Watson computer has been used as the basis for chatbot-based educational toys for companies such as CogniToys intended to interact with children for educational purposes.
#
# Chatbot creation
# The process of creating a chatbot follows a pattern similar to the development of a web page or a mobile app. It can be divided into Design, Building, Analytics and Maintenance.
#
# Design
# The chatbot design is the process that defines the interaction between the user and the chatbot.The chatbot designer will define the chatbot personality, the questions that will be asked to the users, and the overall interaction.It can be viewed as a subset of the conversational design. In order to speed up this process, designers can use dedicated chatbot design tools, that allow for immediate preview, team collaboration and video export.An important part of the chatbot design is also centered around user testing. User testing can be performed following the same principles that guide the user testing of graphical interfaces.
#
# Building
# The process of building a chatbot can be divided into two main tasks: understanding the user's intent and producing the correct answer. The first task involves understanding the user input. In order to properly understand a user input in a free text form, a Natural Language Processing Engine can be used.The second task may involve different approaches depending on the type of the response that the chatbot will generate.
#
# Analytics
# The usage of the chatbot can be monitored in order to spot potential flaws or problems. It can also provide useful insights that can improve the final user experience.
#
# Maintenance
# To keep chatbots up to speed with changing company products and services, traditional chatbot development platforms require ongoing maintenance. This can either be in the form of an ongoing service provider or for larger enterprises in the form of an in-house chatbot training team.To eliminate these costs, some startups are experimenting with Artificial Intelligence to develop self-learning chatbots, particularly in Customer Service applications.
#
# Chatbot development platforms
# The process of building, testing and deploying chatbots can be done on cloud based chatbot development platforms offered by cloud Platform as a Service (PaaS) providers such as Yekaliva, Oracle Cloud Platform, SnatchBot and IBM Watson.These cloud platforms provide Natural Language Processing, Artificial Intelligence and Mobile Backend as a Service for chatbot development.
#
# APIs
# There are many APIs available for building your own chatbots, such as AARC.
#
# Malicious use
# Malicious chatbots are frequently used to fill chat rooms with spam and advertisements, by mimicking human behaviour and conversations or to entice people into revealing personal information, such as bank account numbers. They are commonly found on Yahoo! Messenger, Windows Live Messenger, AOL Instant Messenger and other instant messaging protocols. There has also been a published report of a chatbot used in a fake personal ad on a dating service's website.
# C:\Users\GAYATHRI\OneDrive\Documents\SRET-I YR- MSC\TERM III\Machine Learning\FinalProject\E7122002_ML_FA.pdf
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [3], in <cell line: 5>()
#       7 print(filen)
#       9 with open(filen, 'r', encoding='utf-8') as f:
# ---> 10     content = f.read()
#      11     print(content)
#
# File ~\anaconda3\lib\codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
# --> 322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323     # keep undecoded input until the next call
#     324     self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte

# %%
import glob
text_files=glob.glob(r"C:\Users\GAYATHRI\OneDrive\Documents\SRET-I YR- MSC\TERM III\Machine Learning\FinalProject\chatbot.txt")
print(text_files)
for i in text_files[:20]:
    with open(i,"r")as f:
        d=f.read()
        print(d)
# Out:
# ['C:\\Users\\GAYATHRI\\OneDrive\\Documents\\SRET-I YR- MSC\\TERM III\\Machine Learning\\FinalProject\\chatbot.txt']
# A chatbot (also known as a talkbot, chatterbot, Bot, IM bot, interactive agent, or Artificial Conversational Entity) is a computer program or an artificial intelligence which conducts a conversation via auditory or textual methods. Such programs are often designed to convincingly simulate how a human would behave as a conversational partner, thereby passing the Turing test. Chatbots are typically used in dialog systems for various practical purposes including customer service or information acquisition. Some chatterbots use sophisticated natural language processing systems, but many simpler systems scan for keywords within the input, then pull a reply with the most matching keywords, or the most similar wording pattern, from a database.
#
# The term "ChatterBot" was originally coined by Michael Mauldin (creator of the first Verbot, Julia) in 1994 to describe these conversational programs.Today, most chatbots are either accessed via virtual assistants such as Google Assistant and Amazon Alexa, via messaging apps such as Facebook Messenger or WeChat, or via individual organizations' apps and websites. Chatbots can be classified into usage categories such as conversational commerce (e-commerce via chat), analytics, communication, customer support, design, developer tools, education, entertainment, finance, food, games, health, HR, marketing, news, personal, productivity, shopping, social, sports, travel and utilities.
# Background
# In 1950, Alan Turing's famous article "Computing Machinery and Intelligence" was published, which proposed what is now called the Turing test as a criterion of intelligence. This criterion depends on the ability of a computer program to impersonate a human in a real-time written conversation with a human judge, sufficiently well that the judge is unable to distinguish reliablyâ€”on the basis of the conversational content aloneâ€”between the program and a real human. The notoriety of Turing's proposed test stimulated great interest in Joseph Weizenbaum's program ELIZA, published in 1966, which seemed to be able to fool users into believing that they were conversing with a real human. However Weizenbaum himself did not claim that ELIZA was genuinely intelligent, and the Introduction to his paper presented it more as a debunking exercise:
#
# [In] artificial intelligence ... machines are made to behave in wondrous ways, often sufficient to dazzle even the most experienced observer. But once a particular program is unmasked, once its inner workings are explained ... its magic crumbles away; it stands revealed as a mere collection of procedures ... The observer says to himself "I could have written that". With that thought he moves the program in question from the shelf marked "intelligent", to that reserved for curios ... The object of this paper is to cause just such a re-evaluation of the program about to be "explained". Few programs ever needed it more.
#
# ELIZA's key method of operation (copied by chatbot designers ever since) involves the recognition of cue words or phrases in the input, and the output of corresponding pre-prepared or pre-programmed responses that can move the conversation forward in an apparently meaningful way (e.g. by responding to any input that contains the word 'MOTHER' with 'TELL ME MORE ABOUT YOUR FAMILY').Thus an illusion of understanding is generated, even though the processing involved has been merely superficial. ELIZA showed that such an illusion is surprisingly easy to generate, because human judges are so ready to give the benefit of the doubt when conversational responses are capable of being interpreted as "intelligent".
#
# Interface designers have come to appreciate that humans' readiness to interpret computer output as genuinely conversationalâ€”even when it is actually based on rather simple pattern-matchingâ€”can be exploited for useful purposes. Most people prefer to engage with programs that are human-like, and this gives chatbot-style techniques a potentially useful role in interactive systems that need to elicit information from users, as long as that information is relatively straightforward and falls into predictable categories. Thus, for example, online help systems can usefully employ chatbot techniques to identify the area of help that users require, potentially providing a "friendlier" interface than a more formal search or menu system. This sort of usage holds the prospect of moving chatbot technology from Weizenbaum's "shelf ... reserved for curios" to that marked "genuinely useful computational methods".
#
# Development
# The classic historic early chatbots are ELIZA (1966) and PARRY (1972).More recent notable programs include A.L.I.C.E., Jabberwacky and D.U.D.E (Agence Nationale de la Recherche and CNRS 2006). While ELIZA and PARRY were used exclusively to simulate typed conversation, many chatbots now include functional features such as games and web searching abilities. In 1984, a book called The Policeman's Beard is Half Constructed was published, allegedly written by the chatbot Racter (though the program as released would not have been capable of doing so).
#
# One pertinent field of AI research is natural language processing. Usually, weak AI fields employ specialized software or programming languages created specifically for the narrow function required. For example, A.L.I.C.E. uses a markup language called AIML, which is specific to its function as a conversational agent, and has since been adopted by various other developers of, so called, Alicebots. Nevertheless, A.L.I.C.E. is still purely based on pattern matching techniques without any reasoning capabilities, the same technique ELIZA was using back in 1966. This is not strong AI, which would require sapience and logical reasoning abilities.
#
# Jabberwacky learns new responses and context based on real-time user interactions, rather than being driven from a static database. Some more recent chatbots also combine real-time learning with evolutionary algorithms that optimise their ability to communicate based on each conversation held. Still, there is currently no general purpose conversational artificial intelligence, and some software developers focus on the practical aspect, information retrieval.
#
# Chatbot competitions focus on the Turing test or more specific goals. Two such annual contests are the Loebner Prize and The Chatterbox Challenge (offline since 2015, materials can still be found from web archives).
#
# According to Forrester (2015), AI will replace 16 percent of American jobs by the end of the decade.Chatbots have been used in applications such as customer service, sales and product education. However, a study conducted by Narrative Science in 2015 found that 80 percent of their respondents believe AI improves worker performance and creates jobs.[citation needed]
#
# Application
# See also: Virtual assistant
#
# Aeromexico airline chatbot running on Facebook Messenger, March 2018
# Messaging apps
# Many companies' chatbots run on messaging apps like Facebook Messenger (since 2016), WeChat (since 2013),WhatsApp, LiveChat, Kik, Slack, Line, Telegram, or simply via SMS. They are used for B2C customer service, sales and marketing.
#
# In 2016, Facebook Messenger allowed developers to place chatbots on their platform. There were 30,000 bots created for Messenger in the first six months, rising to 100,000 by September 2017.
#
# Since September 2017, this has also been as part of a pilot program on WhatsApp. Airlines KLM and AeromÃ©xico both announced their participation in the testing;both airlines had previously launched customer services on the Facebook Messenger platform.
#
# The bots usually appear as one of the user's contacts, but can sometimes act as participants in a group chat.
#
# Many banks and insurers, media and e-commerce companies, airlines and hotel chains, retailers, health care providers, government entities and restaurant chains have used chatbots to answer simple questions, increase customer engagement,for promotion, and to offer additional ways to order from them.
#
# A 2017 study showed 4% of companies used chatbots.According to a 2016 study, 80% of businesses said they intended to have one by 2020.
#
# As part of company apps and websites
# Previous generations of chatbots were present on company websites, e.g. Ask Jenn from Alaska Airlines which debuted in 2008 or Expedia's virtual customer service agent which launched in 2011.The newer generation of chatbots includes IBM Watson-powered "Rocky", introduced in February 2017 by the New York City-based e-commerce company Rare Carat to provide information to prospective diamond buyers.
#
# Company internal platforms
# Other companies explore ways they can use chatbots internally, for example for Customer Support, Human Resources, or even in Internet-of-Things (IoT) projects. Overstock.com, for one, has reportedly launched a chatbot named Mila to automate certain simple yet time-consuming processes when requesting for a sick leave.Other large companies such as Lloyds Banking Group, Royal Bank of Scotland, Renault and CitroÃ«n are now using automated online assistants instead of call centres with humans to provide a first point of contact. A SaaS chatbot business ecosystem has been steadily growing since the F8 Conference when Zuckerberg unveiled that Messenger would allow chatbots into the app.
#
# Toys
# Chatbots have also been incorporated into devices not primarily meant for computing such as toys.
#
# Hello Barbie is an Internet-connected version of the doll that uses a chatbot provided by the company ToyTalk,which previously used the chatbot for a range of smartphone-based characters for children.These characters' behaviors are constrained by a set of rules that in effect emulate a particular character and produce a storyline.
#
# IBM's Watson computer has been used as the basis for chatbot-based educational toys for companies such as CogniToys intended to interact with children for educational purposes.
#
# Chatbot creation
# The process of creating a chatbot follows a pattern similar to the development of a web page or a mobile app. It can be divided into Design, Building, Analytics and Maintenance.
#
# Design
# The chatbot design is the process that defines the interaction between the user and the chatbot.The chatbot designer will define the chatbot personality, the questions that will be asked to the users, and the overall interaction.It can be viewed as a subset of the conversational design. In order to speed up this process, designers can use dedicated chatbot design tools, that allow for immediate preview, team collaboration and video export.An important part of the chatbot design is also centered around user testing. User testing can be performed following the same principles that guide the user testing of graphical interfaces.
#
# Building
# The process of building a chatbot can be divided into two main tasks: understanding the user's intent and producing the correct answer. The first task involves understanding the user input. In order to properly understand a user input in a free text form, a Natural Language Processing Engine can be used.The second task may involve different approaches depending on the type of the response that the chatbot will generate.
#
# Analytics
# The usage of the chatbot can be monitored in order to spot potential flaws or problems. It can also provide useful insights that can improve the final user experience.
#
# Maintenance
# To keep chatbots up to speed with changing company products and services, traditional chatbot development platforms require ongoing maintenance. This can either be in the form of an ongoing service provider or for larger enterprises in the form of an in-house chatbot training team.To eliminate these costs, some startups are experimenting with Artificial Intelligence to develop self-learning chatbots, particularly in Customer Service applications.
#
# Chatbot development platforms
# The process of building, testing and deploying chatbots can be done on cloud based chatbot development platforms offered by cloud Platform as a Service (PaaS) providers such as Yekaliva, Oracle Cloud Platform, SnatchBot and IBM Watson.These cloud platforms provide Natural Language Processing, Artificial Intelligence and Mobile Backend as a Service for chatbot development.
#
# APIs
# There are many APIs available for building your own chatbots, such as AARC.
#
# Malicious use
# Malicious chatbots are frequently used to fill chat rooms with spam and advertisements, by mimicking human behaviour and conversations or to entice people into revealing personal information, such as bank account numbers. They are commonly found on Yahoo! Messenger, Windows Live Messenger, AOL Instant Messenger and other instant messaging protocols. There has also been a published report of a chatbot used in a fake personal ad on a dating service's website.

# %% [markdown]
# # Installing NLTK Packages

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
AI_tokens=word_tokenize(content)
AI_tokens
# Out:
# [nltk_data] Error loading punkt: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# ['A',
#  'chatbot',
#  '(',
#  'also',
#  'known',
#  'as',
#  'a',
#  'talkbot',
#  ',',
#  'chatterbot',
#  ',',
#  'Bot',
#  ',',
#  'IM',
#  'bot',
#  ',',
#  'interactive',
#  'agent',
#  ',',
#  'or',
#  'Artificial',
#  'Conversational',
#  'Entity',
#  ')',
#  'is',
#  'a',
#  'computer',
#  'program',
#  'or',
#  'an',
#  'artificial',
#  'intelligence',
#  'which',
#  'conducts',
#  'a',
#  'conversation',
#  'via',
#  'auditory',
#  'or',
#  'textual',
#  'methods',
#  '.',
#  'Such',
#  'programs',
#  'are',
#  'often',
#  'designed',
#  'to',
#  'convincingly',
#  'simulate',
#  'how',
#  'a',
#  'human',
#  'would',
#  'behave',
#  'as',
#  'a',
#  'conversational',
#  'partner',
#  ',',
#  'thereby',
#  'passing',
#  'the',
#  'Turing',
#  'test',
#  '.',
#  'Chatbots',
#  'are',
#  'typically',
#  'used',
#  'in',
#  'dialog',
#  'systems',
#  'for',
#  'various',
#  'practical',
#  'purposes',
#  'including',
#  'customer',
#  'service',
#  'or',
#  'information',
#  'acquisition',
#  '.',
#  'Some',
#  'chatterbots',
#  'use',
#  'sophisticated',
#  'natural',
#  'language',
#  'processing',
#  'systems',
#  ',',
#  'but',
#  'many',
#  'simpler',
#  'systems',
#  'scan',
#  'for',
#  'keywords',
#  'within',
#  'the',
#  'input',
#  ',',
#  'then',
#  'pull',
#  'a',
#  'reply',
#  'with',
#  'the',
#  'most',
#  'matching',
#  'keywords',
#  ',',
#  'or',
#  'the',
#  'most',
#  'similar',
#  'wording',
#  'pattern',
#  ',',
#  'from',
#  'a',
#  'database',
#  '.',
#  'The',
#  'term',
#  '``',
#  'ChatterBot',
#  "''",
#  'was',
#  'originally',
#  'coined',
#  'by',
#  'Michael',
#  'Mauldin',
#  '(',
#  'creator',
#  'of',
#  'the',
#  'first',
#  'Verbot',
#  ',',
#  'Julia',
#  ')',
#  'in',
#  '1994',
#  'to',
#  'describe',
#  'these',
#  'conversational',
#  'programs.Today',
#  ',',
#  'most',
#  'chatbots',
#  'are',
#  'either',
#  'accessed',
#  'via',
#  'virtual',
#  'assistants',
#  'such',
#  'as',
#  'Google',
#  'Assistant',
#  'and',
#  'Amazon',
#  'Alexa',
#  ',',
#  'via',
#  'messaging',
#  'apps',
#  'such',
#  'as',
#  'Facebook',
#  'Messenger',
#  'or',
#  'WeChat',
#  ',',
#  'or',
#  'via',
#  'individual',
#  'organizations',
#  "'",
#  'apps',
#  'and',
#  'websites',
#  '.',
#  'Chatbots',
#  'can',
#  'be',
#  'classified',
#  'into',
#  'usage',
#  'categories',
#  'such',
#  'as',
#  'conversational',
#  'commerce',
#  '(',
#  'e-commerce',
#  'via',
#  'chat',
#  ')',
#  ',',
#  'analytics',
#  ',',
#  'communication',
#  ',',
#  'customer',
#  'support',
#  ',',
#  'design',
#  ',',
#  'developer',
#  'tools',
#  ',',
#  'education',
#  ',',
#  'entertainment',
#  ',',
#  'finance',
#  ',',
#  'food',
#  ',',
#  'games',
#  ',',
#  'health',
#  ',',
#  'HR',
#  ',',
#  'marketing',
#  ',',
#  'news',
#  ',',
#  'personal',
#  ',',
#  'productivity',
#  ',',
#  'shopping',
#  ',',
#  'social',
#  ',',
#  'sports',
#  ',',
#  'travel',
#  'and',
#  'utilities',
#  '.',
#  'Background',
#  'In',
#  '1950',
#  ',',
#  'Alan',
#  'Turing',
#  "'s",
#  'famous',
#  'article',
#  '``',
#  'Computing',
#  'Machinery',
#  'and',
#  'Intelligence',
#  "''",
#  'was',
#  'published',
#  ',',
#  'which',
#  'proposed',
#  'what',
#  'is',
#  'now',
#  'called',
#  'the',
#  'Turing',
#  'test',
#  'as',
#  'a',
#  'criterion',
#  'of',
#  'intelligence',
#  '.',
#  'This',
#  'criterion',
#  'depends',
#  'on',
#  'the',
#  'ability',
#  'of',
#  'a',
#  'computer',
#  'program',
#  'to',
#  'impersonate',
#  'a',
#  'human',
#  'in',
#  'a',
#  'real-time',
#  'written',
#  'conversation',
#  'with',
#  'a',
#  'human',
#  'judge',
#  ',',
#  'sufficiently',
#  'well',
#  'that',
#  'the',
#  'judge',
#  'is',
#  'unable',
#  'to',
#  'distinguish',
#  'reliably—on',
#  'the',
#  'basis',
#  'of',
#  'the',
#  'conversational',
#  'content',
#  'alone—between',
#  'the',
#  'program',
#  'and',
#  'a',
#  'real',
#  'human',
#  '.',
#  'The',
#  'notoriety',
#  'of',
#  'Turing',
#  "'s",
#  'proposed',
#  'test',
#  'stimulated',
#  'great',
#  'interest',
#  'in',
#  'Joseph',
#  'Weizenbaum',
#  "'s",
#  'program',
#  'ELIZA',
#  ',',
#  'published',
#  'in',
#  '1966',
#  ',',
#  'which',
#  'seemed',
#  'to',
#  'be',
#  'able',
#  'to',
#  'fool',
#  'users',
#  'into',
#  'believing',
#  'that',
#  'they',
#  'were',
#  'conversing',
#  'with',
#  'a',
#  'real',
#  'human',
#  '.',
#  'However',
#  'Weizenbaum',
#  'himself',
#  'did',
#  'not',
#  'claim',
#  'that',
#  'ELIZA',
#  'was',
#  'genuinely',
#  'intelligent',
#  ',',
#  'and',
#  'the',
#  'Introduction',
#  'to',
#  'his',
#  'paper',
#  'presented',
#  'it',
#  'more',
#  'as',
#  'a',
#  'debunking',
#  'exercise',
#  ':',
#  '[',
#  'In',
#  ']',
#  'artificial',
#  'intelligence',
#  '...',
#  'machines',
#  'are',
#  'made',
#  'to',
#  'behave',
#  'in',
#  'wondrous',
#  'ways',
#  ',',
#  'often',
#  'sufficient',
#  'to',
#  'dazzle',
#  'even',
#  'the',
#  'most',
#  'experienced',
#  'observer',
#  '.',
#  'But',
#  'once',
#  'a',
#  'particular',
#  'program',
#  'is',
#  'unmasked',
#  ',',
#  'once',
#  'its',
#  'inner',
#  'workings',
#  'are',
#  'explained',
#  '...',
#  'its',
#  'magic',
#  'crumbles',
#  'away',
#  ';',
#  'it',
#  'stands',
#  'revealed',
#  'as',
#  'a',
#  'mere',
#  'collection',
#  'of',
#  'procedures',
#  '...',
#  'The',
#  'observer',
#  'says',
#  'to',
#  'himself',
#  '``',
#  'I',
#  'could',
#  'have',
#  'written',
#  'that',
#  "''",
#  '.',
#  'With',
#  'that',
#  'thought',
#  'he',
#  'moves',
#  'the',
#  'program',
#  'in',
#  'question',
#  'from',
#  'the',
#  'shelf',
#  'marked',
#  '``',
#  'intelligent',
#  "''",
#  ',',
#  'to',
#  'that',
#  'reserved',
#  'for',
#  'curios',
#  '...',
#  'The',
#  'object',
#  'of',
#  'this',
#  'paper',
#  'is',
#  'to',
#  'cause',
#  'just',
#  'such',
#  'a',
#  're-evaluation',
#  'of',
#  'the',
#  'program',
#  'about',
#  'to',
#  'be',
#  '``',
#  'explained',
#  "''",
#  '.',
#  'Few',
#  'programs',
#  'ever',
#  'needed',
#  'it',
#  'more',
#  '.',
#  'ELIZA',
#  "'s",
#  'key',
#  'method',
#  'of',
#  'operation',
#  '(',
#  'copied',
#  'by',
#  'chatbot',
#  'designers',
#  'ever',
#  'since',
#  ')',
#  'involves',
#  'the',
#  'recognition',
#  'of',
#  'cue',
#  'words',
#  'or',
#  'phrases',
#  'in',
#  'the',
#  'input',
#  ',',
#  'and',
#  'the',
#  'output',
#  'of',
#  'corresponding',
#  'pre-prepared',
#  'or',
#  'pre-programmed',
#  'responses',
#  'that',
#  'can',
#  'move',
#  'the',
#  'conversation',
#  'forward',
#  'in',
#  'an',
#  'apparently',
#  'meaningful',
#  'way',
#  '(',
#  'e.g',
#  '.',
#  'by',
#  'responding',
#  'to',
#  'any',
#  'input',
#  'that',
#  'contains',
#  'the',
#  'word',
#  "'MOTHER",
#  "'",
#  'with',
#  "'TELL",
#  'ME',
#  'MORE',
#  'ABOUT',
#  'YOUR',
#  'FAMILY',
#  "'",
#  ')',
#  '.Thus',
#  'an',
#  'illusion',
#  'of',
#  'understanding',
#  'is',
#  'generated',
#  ',',
#  'even',
#  'though',
#  'the',
#  'processing',
#  'involved',
#  'has',
#  'been',
#  'merely',
#  'superficial',
#  '.',
#  'ELIZA',
#  'showed',
#  'that',
#  'such',
#  'an',
#  'illusion',
#  'is',
#  'surprisingly',
#  'easy',
#  'to',
#  'generate',
#  ',',
#  'because',
#  'human',
#  'judges',
#  'are',
#  'so',
#  'ready',
#  'to',
#  'give',
#  'the',
#  'benefit',
#  'of',
#  'the',
#  'doubt',
#  'when',
#  'conversational',
#  'responses',
#  'are',
#  'capable',
#  'of',
#  'being',
#  'interpreted',
#  'as',
#  '``',
#  'intelligent',
#  "''",
#  '.',
#  'Interface',
#  'designers',
#  'have',
#  'come',
#  'to',
#  'appreciate',
#  'that',
#  'humans',
#  "'",
#  'readiness',
#  'to',
#  'interpret',
#  'computer',
#  'output',
#  'as',
#  'genuinely',
#  'conversational—even',
#  'when',
#  'it',
#  'is',
#  'actually',
#  'based',
#  'on',
#  'rather',
#  'simple',
#  'pattern-matching—can',
#  'be',
#  'exploited',
#  'for',
#  'useful',
#  'purposes',
#  '.',
#  'Most',
#  'people',
#  'prefer',
#  'to',
#  'engage',
#  'with',
#  'programs',
#  'that',
#  'are',
#  'human-like',
#  ',',
#  'and',
#  'this',
#  'gives',
#  'chatbot-style',
#  'techniques',
#  'a',
#  'potentially',
#  'useful',
#  'role',
#  'in',
#  'interactive',
#  'systems',
#  'that',
#  'need',
#  'to',
#  'elicit',
#  'information',
#  'from',
#  'users',
#  ',',
#  'as',
#  'long',
#  'as',
#  'that',
#  'information',
#  'is',
#  'relatively',
#  'straightforward',
#  'and',
#  'falls',
#  'into',
#  'predictable',
#  'categories',
#  '.',
#  'Thus',
#  ',',
#  'for',
#  'example',
#  ',',
#  'online',
#  'help',
#  'systems',
#  'can',
#  'usefully',
#  'employ',
#  'chatbot',
#  'techniques',
#  'to',
#  'identify',
#  'the',
#  'area',
#  'of',
#  'help',
#  'that',
#  'users',
#  'require',
#  ',',
#  'potentially',
#  'providing',
#  'a',
#  '``',
#  'friendlier',
#  "''",
#  'interface',
#  'than',
#  'a',
#  'more',
#  'formal',
#  'search',
#  'or',
#  'menu',
#  'system',
#  '.',
#  'This',
#  'sort',
#  'of',
#  'usage',
#  'holds',
#  'the',
#  'prospect',
#  'of',
#  'moving',
#  'chatbot',
#  'technology',
#  'from',
#  'Weizenbaum',
#  "'s",
#  '``',
#  'shelf',
#  '...',
#  'reserved',
#  'for',
#  'curios',
#  "''",
#  'to',
#  'that',
#  'marked',
#  '``',
#  'genuinely',
#  'useful',
#  'computational',
#  'methods',
#  "''",
#  '.',
#  'Development',
#  'The',
#  'classic',
#  'historic',
#  'early',
#  'chatbots',
#  'are',
#  'ELIZA',
#  '(',
#  '1966',
#  ')',
#  'and',
#  'PARRY',
#  '(',
#  '1972',
#  ')',
#  '.More',
#  'recent',
#  'notable',
#  'programs',
#  'include',
#  'A.L.I.C.E.',
#  ',',
#  'Jabberwacky',
#  'and',
#  'D.U.D.E',
#  '(',
#  'Agence',
#  'Nationale',
#  'de',
#  'la',
#  'Recherche',
#  'and',
#  'CNRS',
#  '2006',
#  ')',
#  '.',
#  'While',
#  'ELIZA',
#  'and',
#  'PARRY',
#  'were',
#  'used',
#  'exclusively',
#  'to',
#  'simulate',
#  'typed',
#  'conversation',
#  ',',
#  'many',
#  'chatbots',
#  'now',
#  'include',
#  'functional',
#  'features',
#  'such',
#  'as',
#  'games',
#  'and',
#  'web',
#  'searching',
#  'abilities',
#  '.',
#  'In',
#  '1984',
#  ',',
#  'a',
#  'book',
#  'called',
#  'The',
#  'Policeman',
#  "'s",
#  'Beard',
#  'is',
#  'Half',
#  'Constructed',
#  'was',
#  'published',
#  ',',
#  'allegedly',
#  'written',
#  'by',
#  'the',
#  'chatbot',
#  'Racter',
#  '(',
#  'though',
#  'the',
#  'program',
#  'as',
#  'released',
#  'would',
#  'not',
#  'have',
#  'been',
#  'capable',
#  'of',
#  'doing',
#  'so',
#  ')',
#  '.',
#  'One',
#  'pertinent',
#  'field',
#  'of',
#  'AI',
#  'research',
#  'is',
#  'natural',
#  'language',
#  'processing',
#  '.',
#  'Usually',
#  ',',
#  'weak',
#  'AI',
#  'fields',
#  'employ',
#  'specialized',
#  'software',
#  'or',
#  'programming',
#  'languages',
#  'created',
#  'specifically',
#  'for',
#  'the',
#  'narrow',
#  'function',
#  'required',
#  '.',
#  'For',
#  'example',
#  ',',
#  'A.L.I.C.E',
#  '.',
#  'uses',
#  'a',
#  'markup',
#  'language',
#  'called',
#  'AIML',
#  ',',
#  'which',
#  'is',
#  'specific',
#  'to',
#  'its',
#  'function',
#  'as',
#  'a',
#  'conversational',
#  'agent',
#  ',',
#  'and',
#  'has',
#  'since',
#  'been',
#  'adopted',
#  'by',
#  'various',
#  'other',
#  'developers',
#  'of',
#  ',',
#  'so',
#  'called',
#  ',',
#  'Alicebots',
#  '.',
#  'Nevertheless',
#  ',',
#  'A.L.I.C.E',
#  '.',
#  'is',
#  'still',
#  'purely',
#  'based',
#  'on',
#  'pattern',
#  'matching',
#  'techniques',
#  'without',
#  'any',
#  'reasoning',
#  'capabilities',
#  ',',
#  'the',
#  'same',
#  'technique',
#  'ELIZA',
#  'was',
#  'using',
#  'back',
#  'in',
#  '1966',
#  '.',
#  'This',
#  'is',
#  'not',
#  'strong',
#  'AI',
#  ',',
#  'which',
#  'would',
#  'require',
#  'sapience',
#  'and',
#  'logical',
#  'reasoning',
#  'abilities',
#  '.',
#  ...]

# %%
len(AI_tokens)
# Out:
# 2191

# %%
from nltk.probability import FreqDist
fdist=FreqDist()
for word in AI_tokens:
    fdist[word.lower()]+=1
fdist
# Out:
# FreqDist({',': 125, 'the': 83, '.': 71, 'a': 55, 'to': 48, 'of': 48, 'and': 43, 'in': 33, 'as': 30, 'chatbot': 27, ...})

# %%
fdist_top5=fdist.most_common(10)
fdist_top5
# Out:
# [(',', 125),
#  ('the', 83),
#  ('.', 71),
#  ('a', 55),
#  ('to', 48),
#  ('of', 48),
#  ('and', 43),
#  ('in', 33),
#  ('as', 30),
#  ('chatbot', 27)]

# %%
from nltk.tokenize import blankline_tokenize
AI_blank=blankline_tokenize(content)
len(AI_blank)
# Out:
# 30

# %%
from nltk.util import bigrams,trigrams,ngrams
string="The best and most beautiful things in the world cannot be seen or even touched, they must be felt with the heart"
quotes_tokens=nltk.word_tokenize(content)
quotes_tokens
# Out:
# ['A',
#  'chatbot',
#  '(',
#  'also',
#  'known',
#  'as',
#  'a',
#  'talkbot',
#  ',',
#  'chatterbot',
#  ',',
#  'Bot',
#  ',',
#  'IM',
#  'bot',
#  ',',
#  'interactive',
#  'agent',
#  ',',
#  'or',
#  'Artificial',
#  'Conversational',
#  'Entity',
#  ')',
#  'is',
#  'a',
#  'computer',
#  'program',
#  'or',
#  'an',
#  'artificial',
#  'intelligence',
#  'which',
#  'conducts',
#  'a',
#  'conversation',
#  'via',
#  'auditory',
#  'or',
#  'textual',
#  'methods',
#  '.',
#  'Such',
#  'programs',
#  'are',
#  'often',
#  'designed',
#  'to',
#  'convincingly',
#  'simulate',
#  'how',
#  'a',
#  'human',
#  'would',
#  'behave',
#  'as',
#  'a',
#  'conversational',
#  'partner',
#  ',',
#  'thereby',
#  'passing',
#  'the',
#  'Turing',
#  'test',
#  '.',
#  'Chatbots',
#  'are',
#  'typically',
#  'used',
#  'in',
#  'dialog',
#  'systems',
#  'for',
#  'various',
#  'practical',
#  'purposes',
#  'including',
#  'customer',
#  'service',
#  'or',
#  'information',
#  'acquisition',
#  '.',
#  'Some',
#  'chatterbots',
#  'use',
#  'sophisticated',
#  'natural',
#  'language',
#  'processing',
#  'systems',
#  ',',
#  'but',
#  'many',
#  'simpler',
#  'systems',
#  'scan',
#  'for',
#  'keywords',
#  'within',
#  'the',
#  'input',
#  ',',
#  'then',
#  'pull',
#  'a',
#  'reply',
#  'with',
#  'the',
#  'most',
#  'matching',
#  'keywords',
#  ',',
#  'or',
#  'the',
#  'most',
#  'similar',
#  'wording',
#  'pattern',
#  ',',
#  'from',
#  'a',
#  'database',
#  '.',
#  'The',
#  'term',
#  '``',
#  'ChatterBot',
#  "''",
#  'was',
#  'originally',
#  'coined',
#  'by',
#  'Michael',
#  'Mauldin',
#  '(',
#  'creator',
#  'of',
#  'the',
#  'first',
#  'Verbot',
#  ',',
#  'Julia',
#  ')',
#  'in',
#  '1994',
#  'to',
#  'describe',
#  'these',
#  'conversational',
#  'programs.Today',
#  ',',
#  'most',
#  'chatbots',
#  'are',
#  'either',
#  'accessed',
#  'via',
#  'virtual',
#  'assistants',
#  'such',
#  'as',
#  'Google',
#  'Assistant',
#  'and',
#  'Amazon',
#  'Alexa',
#  ',',
#  'via',
#  'messaging',
#  'apps',
#  'such',
#  'as',
#  'Facebook',
#  'Messenger',
#  'or',
#  'WeChat',
#  ',',
#  'or',
#  'via',
#  'individual',
#  'organizations',
#  "'",
#  'apps',
#  'and',
#  'websites',
#  '.',
#  'Chatbots',
#  'can',
#  'be',
#  'classified',
#  'into',
#  'usage',
#  'categories',
#  'such',
#  'as',
#  'conversational',
#  'commerce',
#  '(',
#  'e-commerce',
#  'via',
#  'chat',
#  ')',
#  ',',
#  'analytics',
#  ',',
#  'communication',
#  ',',
#  'customer',
#  'support',
#  ',',
#  'design',
#  ',',
#  'developer',
#  'tools',
#  ',',
#  'education',
#  ',',
#  'entertainment',
#  ',',
#  'finance',
#  ',',
#  'food',
#  ',',
#  'games',
#  ',',
#  'health',
#  ',',
#  'HR',
#  ',',
#  'marketing',
#  ',',
#  'news',
#  ',',
#  'personal',
#  ',',
#  'productivity',
#  ',',
#  'shopping',
#  ',',
#  'social',
#  ',',
#  'sports',
#  ',',
#  'travel',
#  'and',
#  'utilities',
#  '.',
#  'Background',
#  'In',
#  '1950',
#  ',',
#  'Alan',
#  'Turing',
#  "'s",
#  'famous',
#  'article',
#  '``',
#  'Computing',
#  'Machinery',
#  'and',
#  'Intelligence',
#  "''",
#  'was',
#  'published',
#  ',',
#  'which',
#  'proposed',
#  'what',
#  'is',
#  'now',
#  'called',
#  'the',
#  'Turing',
#  'test',
#  'as',
#  'a',
#  'criterion',
#  'of',
#  'intelligence',
#  '.',
#  'This',
#  'criterion',
#  'depends',
#  'on',
#  'the',
#  'ability',
#  'of',
#  'a',
#  'computer',
#  'program',
#  'to',
#  'impersonate',
#  'a',
#  'human',
#  'in',
#  'a',
#  'real-time',
#  'written',
#  'conversation',
#  'with',
#  'a',
#  'human',
#  'judge',
#  ',',
#  'sufficiently',
#  'well',
#  'that',
#  'the',
#  'judge',
#  'is',
#  'unable',
#  'to',
#  'distinguish',
#  'reliably—on',
#  'the',
#  'basis',
#  'of',
#  'the',
#  'conversational',
#  'content',
#  'alone—between',
#  'the',
#  'program',
#  'and',
#  'a',
#  'real',
#  'human',
#  '.',
#  'The',
#  'notoriety',
#  'of',
#  'Turing',
#  "'s",
#  'proposed',
#  'test',
#  'stimulated',
#  'great',
#  'interest',
#  'in',
#  'Joseph',
#  'Weizenbaum',
#  "'s",
#  'program',
#  'ELIZA',
#  ',',
#  'published',
#  'in',
#  '1966',
#  ',',
#  'which',
#  'seemed',
#  'to',
#  'be',
#  'able',
#  'to',
#  'fool',
#  'users',
#  'into',
#  'believing',
#  'that',
#  'they',
#  'were',
#  'conversing',
#  'with',
#  'a',
#  'real',
#  'human',
#  '.',
#  'However',
#  'Weizenbaum',
#  'himself',
#  'did',
#  'not',
#  'claim',
#  'that',
#  'ELIZA',
#  'was',
#  'genuinely',
#  'intelligent',
#  ',',
#  'and',
#  'the',
#  'Introduction',
#  'to',
#  'his',
#  'paper',
#  'presented',
#  'it',
#  'more',
#  'as',
#  'a',
#  'debunking',
#  'exercise',
#  ':',
#  '[',
#  'In',
#  ']',
#  'artificial',
#  'intelligence',
#  '...',
#  'machines',
#  'are',
#  'made',
#  'to',
#  'behave',
#  'in',
#  'wondrous',
#  'ways',
#  ',',
#  'often',
#  'sufficient',
#  'to',
#  'dazzle',
#  'even',
#  'the',
#  'most',
#  'experienced',
#  'observer',
#  '.',
#  'But',
#  'once',
#  'a',
#  'particular',
#  'program',
#  'is',
#  'unmasked',
#  ',',
#  'once',
#  'its',
#  'inner',
#  'workings',
#  'are',
#  'explained',
#  '...',
#  'its',
#  'magic',
#  'crumbles',
#  'away',
#  ';',
#  'it',
#  'stands',
#  'revealed',
#  'as',
#  'a',
#  'mere',
#  'collection',
#  'of',
#  'procedures',
#  '...',
#  'The',
#  'observer',
#  'says',
#  'to',
#  'himself',
#  '``',
#  'I',
#  'could',
#  'have',
#  'written',
#  'that',
#  "''",
#  '.',
#  'With',
#  'that',
#  'thought',
#  'he',
#  'moves',
#  'the',
#  'program',
#  'in',
#  'question',
#  'from',
#  'the',
#  'shelf',
#  'marked',
#  '``',
#  'intelligent',
#  "''",
#  ',',
#  'to',
#  'that',
#  'reserved',
#  'for',
#  'curios',
#  '...',
#  'The',
#  'object',
#  'of',
#  'this',
#  'paper',
#  'is',
#  'to',
#  'cause',
#  'just',
#  'such',
#  'a',
#  're-evaluation',
#  'of',
#  'the',
#  'program',
#  'about',
#  'to',
#  'be',
#  '``',
#  'explained',
#  "''",
#  '.',
#  'Few',
#  'programs',
#  'ever',
#  'needed',
#  'it',
#  'more',
#  '.',
#  'ELIZA',
#  "'s",
#  'key',
#  'method',
#  'of',
#  'operation',
#  '(',
#  'copied',
#  'by',
#  'chatbot',
#  'designers',
#  'ever',
#  'since',
#  ')',
#  'involves',
#  'the',
#  'recognition',
#  'of',
#  'cue',
#  'words',
#  'or',
#  'phrases',
#  'in',
#  'the',
#  'input',
#  ',',
#  'and',
#  'the',
#  'output',
#  'of',
#  'corresponding',
#  'pre-prepared',
#  'or',
#  'pre-programmed',
#  'responses',
#  'that',
#  'can',
#  'move',
#  'the',
#  'conversation',
#  'forward',
#  'in',
#  'an',
#  'apparently',
#  'meaningful',
#  'way',
#  '(',
#  'e.g',
#  '.',
#  'by',
#  'responding',
#  'to',
#  'any',
#  'input',
#  'that',
#  'contains',
#  'the',
#  'word',
#  "'MOTHER",
#  "'",
#  'with',
#  "'TELL",
#  'ME',
#  'MORE',
#  'ABOUT',
#  'YOUR',
#  'FAMILY',
#  "'",
#  ')',
#  '.Thus',
#  'an',
#  'illusion',
#  'of',
#  'understanding',
#  'is',
#  'generated',
#  ',',
#  'even',
#  'though',
#  'the',
#  'processing',
#  'involved',
#  'has',
#  'been',
#  'merely',
#  'superficial',
#  '.',
#  'ELIZA',
#  'showed',
#  'that',
#  'such',
#  'an',
#  'illusion',
#  'is',
#  'surprisingly',
#  'easy',
#  'to',
#  'generate',
#  ',',
#  'because',
#  'human',
#  'judges',
#  'are',
#  'so',
#  'ready',
#  'to',
#  'give',
#  'the',
#  'benefit',
#  'of',
#  'the',
#  'doubt',
#  'when',
#  'conversational',
#  'responses',
#  'are',
#  'capable',
#  'of',
#  'being',
#  'interpreted',
#  'as',
#  '``',
#  'intelligent',
#  "''",
#  '.',
#  'Interface',
#  'designers',
#  'have',
#  'come',
#  'to',
#  'appreciate',
#  'that',
#  'humans',
#  "'",
#  'readiness',
#  'to',
#  'interpret',
#  'computer',
#  'output',
#  'as',
#  'genuinely',
#  'conversational—even',
#  'when',
#  'it',
#  'is',
#  'actually',
#  'based',
#  'on',
#  'rather',
#  'simple',
#  'pattern-matching—can',
#  'be',
#  'exploited',
#  'for',
#  'useful',
#  'purposes',
#  '.',
#  'Most',
#  'people',
#  'prefer',
#  'to',
#  'engage',
#  'with',
#  'programs',
#  'that',
#  'are',
#  'human-like',
#  ',',
#  'and',
#  'this',
#  'gives',
#  'chatbot-style',
#  'techniques',
#  'a',
#  'potentially',
#  'useful',
#  'role',
#  'in',
#  'interactive',
#  'systems',
#  'that',
#  'need',
#  'to',
#  'elicit',
#  'information',
#  'from',
#  'users',
#  ',',
#  'as',
#  'long',
#  'as',
#  'that',
#  'information',
#  'is',
#  'relatively',
#  'straightforward',
#  'and',
#  'falls',
#  'into',
#  'predictable',
#  'categories',
#  '.',
#  'Thus',
#  ',',
#  'for',
#  'example',
#  ',',
#  'online',
#  'help',
#  'systems',
#  'can',
#  'usefully',
#  'employ',
#  'chatbot',
#  'techniques',
#  'to',
#  'identify',
#  'the',
#  'area',
#  'of',
#  'help',
#  'that',
#  'users',
#  'require',
#  ',',
#  'potentially',
#  'providing',
#  'a',
#  '``',
#  'friendlier',
#  "''",
#  'interface',
#  'than',
#  'a',
#  'more',
#  'formal',
#  'search',
#  'or',
#  'menu',
#  'system',
#  '.',
#  'This',
#  'sort',
#  'of',
#  'usage',
#  'holds',
#  'the',
#  'prospect',
#  'of',
#  'moving',
#  'chatbot',
#  'technology',
#  'from',
#  'Weizenbaum',
#  "'s",
#  '``',
#  'shelf',
#  '...',
#  'reserved',
#  'for',
#  'curios',
#  "''",
#  'to',
#  'that',
#  'marked',
#  '``',
#  'genuinely',
#  'useful',
#  'computational',
#  'methods',
#  "''",
#  '.',
#  'Development',
#  'The',
#  'classic',
#  'historic',
#  'early',
#  'chatbots',
#  'are',
#  'ELIZA',
#  '(',
#  '1966',
#  ')',
#  'and',
#  'PARRY',
#  '(',
#  '1972',
#  ')',
#  '.More',
#  'recent',
#  'notable',
#  'programs',
#  'include',
#  'A.L.I.C.E.',
#  ',',
#  'Jabberwacky',
#  'and',
#  'D.U.D.E',
#  '(',
#  'Agence',
#  'Nationale',
#  'de',
#  'la',
#  'Recherche',
#  'and',
#  'CNRS',
#  '2006',
#  ')',
#  '.',
#  'While',
#  'ELIZA',
#  'and',
#  'PARRY',
#  'were',
#  'used',
#  'exclusively',
#  'to',
#  'simulate',
#  'typed',
#  'conversation',
#  ',',
#  'many',
#  'chatbots',
#  'now',
#  'include',
#  'functional',
#  'features',
#  'such',
#  'as',
#  'games',
#  'and',
#  'web',
#  'searching',
#  'abilities',
#  '.',
#  'In',
#  '1984',
#  ',',
#  'a',
#  'book',
#  'called',
#  'The',
#  'Policeman',
#  "'s",
#  'Beard',
#  'is',
#  'Half',
#  'Constructed',
#  'was',
#  'published',
#  ',',
#  'allegedly',
#  'written',
#  'by',
#  'the',
#  'chatbot',
#  'Racter',
#  '(',
#  'though',
#  'the',
#  'program',
#  'as',
#  'released',
#  'would',
#  'not',
#  'have',
#  'been',
#  'capable',
#  'of',
#  'doing',
#  'so',
#  ')',
#  '.',
#  'One',
#  'pertinent',
#  'field',
#  'of',
#  'AI',
#  'research',
#  'is',
#  'natural',
#  'language',
#  'processing',
#  '.',
#  'Usually',
#  ',',
#  'weak',
#  'AI',
#  'fields',
#  'employ',
#  'specialized',
#  'software',
#  'or',
#  'programming',
#  'languages',
#  'created',
#  'specifically',
#  'for',
#  'the',
#  'narrow',
#  'function',
#  'required',
#  '.',
#  'For',
#  'example',
#  ',',
#  'A.L.I.C.E',
#  '.',
#  'uses',
#  'a',
#  'markup',
#  'language',
#  'called',
#  'AIML',
#  ',',
#  'which',
#  'is',
#  'specific',
#  'to',
#  'its',
#  'function',
#  'as',
#  'a',
#  'conversational',
#  'agent',
#  ',',
#  'and',
#  'has',
#  'since',
#  'been',
#  'adopted',
#  'by',
#  'various',
#  'other',
#  'developers',
#  'of',
#  ',',
#  'so',
#  'called',
#  ',',
#  'Alicebots',
#  '.',
#  'Nevertheless',
#  ',',
#  'A.L.I.C.E',
#  '.',
#  'is',
#  'still',
#  'purely',
#  'based',
#  'on',
#  'pattern',
#  'matching',
#  'techniques',
#  'without',
#  'any',
#  'reasoning',
#  'capabilities',
#  ',',
#  'the',
#  'same',
#  'technique',
#  'ELIZA',
#  'was',
#  'using',
#  'back',
#  'in',
#  '1966',
#  '.',
#  'This',
#  'is',
#  'not',
#  'strong',
#  'AI',
#  ',',
#  'which',
#  'would',
#  'require',
#  'sapience',
#  'and',
#  'logical',
#  'reasoning',
#  'abilities',
#  '.',
#  ...]

# %%
quotes_bigrams=list(nltk.bigrams(quotes_tokens))
quotes_bigrams
# Out:
# [('A', 'chatbot'),
#  ('chatbot', '('),
#  ('(', 'also'),
#  ('also', 'known'),
#  ('known', 'as'),
#  ('as', 'a'),
#  ('a', 'talkbot'),
#  ('talkbot', ','),
#  (',', 'chatterbot'),
#  ('chatterbot', ','),
#  (',', 'Bot'),
#  ('Bot', ','),
#  (',', 'IM'),
#  ('IM', 'bot'),
#  ('bot', ','),
#  (',', 'interactive'),
#  ('interactive', 'agent'),
#  ('agent', ','),
#  (',', 'or'),
#  ('or', 'Artificial'),
#  ('Artificial', 'Conversational'),
#  ('Conversational', 'Entity'),
#  ('Entity', ')'),
#  (')', 'is'),
#  ('is', 'a'),
#  ('a', 'computer'),
#  ('computer', 'program'),
#  ('program', 'or'),
#  ('or', 'an'),
#  ('an', 'artificial'),
#  ('artificial', 'intelligence'),
#  ('intelligence', 'which'),
#  ('which', 'conducts'),
#  ('conducts', 'a'),
#  ('a', 'conversation'),
#  ('conversation', 'via'),
#  ('via', 'auditory'),
#  ('auditory', 'or'),
#  ('or', 'textual'),
#  ('textual', 'methods'),
#  ('methods', '.'),
#  ('.', 'Such'),
#  ('Such', 'programs'),
#  ('programs', 'are'),
#  ('are', 'often'),
#  ('often', 'designed'),
#  ('designed', 'to'),
#  ('to', 'convincingly'),
#  ('convincingly', 'simulate'),
#  ('simulate', 'how'),
#  ('how', 'a'),
#  ('a', 'human'),
#  ('human', 'would'),
#  ('would', 'behave'),
#  ('behave', 'as'),
#  ('as', 'a'),
#  ('a', 'conversational'),
#  ('conversational', 'partner'),
#  ('partner', ','),
#  (',', 'thereby'),
#  ('thereby', 'passing'),
#  ('passing', 'the'),
#  ('the', 'Turing'),
#  ('Turing', 'test'),
#  ('test', '.'),
#  ('.', 'Chatbots'),
#  ('Chatbots', 'are'),
#  ('are', 'typically'),
#  ('typically', 'used'),
#  ('used', 'in'),
#  ('in', 'dialog'),
#  ('dialog', 'systems'),
#  ('systems', 'for'),
#  ('for', 'various'),
#  ('various', 'practical'),
#  ('practical', 'purposes'),
#  ('purposes', 'including'),
#  ('including', 'customer'),
#  ('customer', 'service'),
#  ('service', 'or'),
#  ('or', 'information'),
#  ('information', 'acquisition'),
#  ('acquisition', '.'),
#  ('.', 'Some'),
#  ('Some', 'chatterbots'),
#  ('chatterbots', 'use'),
#  ('use', 'sophisticated'),
#  ('sophisticated', 'natural'),
#  ('natural', 'language'),
#  ('language', 'processing'),
#  ('processing', 'systems'),
#  ('systems', ','),
#  (',', 'but'),
#  ('but', 'many'),
#  ('many', 'simpler'),
#  ('simpler', 'systems'),
#  ('systems', 'scan'),
#  ('scan', 'for'),
#  ('for', 'keywords'),
#  ('keywords', 'within'),
#  ('within', 'the'),
#  ('the', 'input'),
#  ('input', ','),
#  (',', 'then'),
#  ('then', 'pull'),
#  ('pull', 'a'),
#  ('a', 'reply'),
#  ('reply', 'with'),
#  ('with', 'the'),
#  ('the', 'most'),
#  ('most', 'matching'),
#  ('matching', 'keywords'),
#  ('keywords', ','),
#  (',', 'or'),
#  ('or', 'the'),
#  ('the', 'most'),
#  ('most', 'similar'),
#  ('similar', 'wording'),
#  ('wording', 'pattern'),
#  ('pattern', ','),
#  (',', 'from'),
#  ('from', 'a'),
#  ('a', 'database'),
#  ('database', '.'),
#  ('.', 'The'),
#  ('The', 'term'),
#  ('term', '``'),
#  ('``', 'ChatterBot'),
#  ('ChatterBot', "''"),
#  ("''", 'was'),
#  ('was', 'originally'),
#  ('originally', 'coined'),
#  ('coined', 'by'),
#  ('by', 'Michael'),
#  ('Michael', 'Mauldin'),
#  ('Mauldin', '('),
#  ('(', 'creator'),
#  ('creator', 'of'),
#  ('of', 'the'),
#  ('the', 'first'),
#  ('first', 'Verbot'),
#  ('Verbot', ','),
#  (',', 'Julia'),
#  ('Julia', ')'),
#  (')', 'in'),
#  ('in', '1994'),
#  ('1994', 'to'),
#  ('to', 'describe'),
#  ('describe', 'these'),
#  ('these', 'conversational'),
#  ('conversational', 'programs.Today'),
#  ('programs.Today', ','),
#  (',', 'most'),
#  ('most', 'chatbots'),
#  ('chatbots', 'are'),
#  ('are', 'either'),
#  ('either', 'accessed'),
#  ('accessed', 'via'),
#  ('via', 'virtual'),
#  ('virtual', 'assistants'),
#  ('assistants', 'such'),
#  ('such', 'as'),
#  ('as', 'Google'),
#  ('Google', 'Assistant'),
#  ('Assistant', 'and'),
#  ('and', 'Amazon'),
#  ('Amazon', 'Alexa'),
#  ('Alexa', ','),
#  (',', 'via'),
#  ('via', 'messaging'),
#  ('messaging', 'apps'),
#  ('apps', 'such'),
#  ('such', 'as'),
#  ('as', 'Facebook'),
#  ('Facebook', 'Messenger'),
#  ('Messenger', 'or'),
#  ('or', 'WeChat'),
#  ('WeChat', ','),
#  (',', 'or'),
#  ('or', 'via'),
#  ('via', 'individual'),
#  ('individual', 'organizations'),
#  ('organizations', "'"),
#  ("'", 'apps'),
#  ('apps', 'and'),
#  ('and', 'websites'),
#  ('websites', '.'),
#  ('.', 'Chatbots'),
#  ('Chatbots', 'can'),
#  ('can', 'be'),
#  ('be', 'classified'),
#  ('classified', 'into'),
#  ('into', 'usage'),
#  ('usage', 'categories'),
#  ('categories', 'such'),
#  ('such', 'as'),
#  ('as', 'conversational'),
#  ('conversational', 'commerce'),
#  ('commerce', '('),
#  ('(', 'e-commerce'),
#  ('e-commerce', 'via'),
#  ('via', 'chat'),
#  ('chat', ')'),
#  (')', ','),
#  (',', 'analytics'),
#  ('analytics', ','),
#  (',', 'communication'),
#  ('communication', ','),
#  (',', 'customer'),
#  ('customer', 'support'),
#  ('support', ','),
#  (',', 'design'),
#  ('design', ','),
#  (',', 'developer'),
#  ('developer', 'tools'),
#  ('tools', ','),
#  (',', 'education'),
#  ('education', ','),
#  (',', 'entertainment'),
#  ('entertainment', ','),
#  (',', 'finance'),
#  ('finance', ','),
#  (',', 'food'),
#  ('food', ','),
#  (',', 'games'),
#  ('games', ','),
#  (',', 'health'),
#  ('health', ','),
#  (',', 'HR'),
#  ('HR', ','),
#  (',', 'marketing'),
#  ('marketing', ','),
#  (',', 'news'),
#  ('news', ','),
#  (',', 'personal'),
#  ('personal', ','),
#  (',', 'productivity'),
#  ('productivity', ','),
#  (',', 'shopping'),
#  ('shopping', ','),
#  (',', 'social'),
#  ('social', ','),
#  (',', 'sports'),
#  ('sports', ','),
#  (',', 'travel'),
#  ('travel', 'and'),
#  ('and', 'utilities'),
#  ('utilities', '.'),
#  ('.', 'Background'),
#  ('Background', 'In'),
#  ('In', '1950'),
#  ('1950', ','),
#  (',', 'Alan'),
#  ('Alan', 'Turing'),
#  ('Turing', "'s"),
#  ("'s", 'famous'),
#  ('famous', 'article'),
#  ('article', '``'),
#  ('``', 'Computing'),
#  ('Computing', 'Machinery'),
#  ('Machinery', 'and'),
#  ('and', 'Intelligence'),
#  ('Intelligence', "''"),
#  ("''", 'was'),
#  ('was', 'published'),
#  ('published', ','),
#  (',', 'which'),
#  ('which', 'proposed'),
#  ('proposed', 'what'),
#  ('what', 'is'),
#  ('is', 'now'),
#  ('now', 'called'),
#  ('called', 'the'),
#  ('the', 'Turing'),
#  ('Turing', 'test'),
#  ('test', 'as'),
#  ('as', 'a'),
#  ('a', 'criterion'),
#  ('criterion', 'of'),
#  ('of', 'intelligence'),
#  ('intelligence', '.'),
#  ('.', 'This'),
#  ('This', 'criterion'),
#  ('criterion', 'depends'),
#  ('depends', 'on'),
#  ('on', 'the'),
#  ('the', 'ability'),
#  ('ability', 'of'),
#  ('of', 'a'),
#  ('a', 'computer'),
#  ('computer', 'program'),
#  ('program', 'to'),
#  ('to', 'impersonate'),
#  ('impersonate', 'a'),
#  ('a', 'human'),
#  ('human', 'in'),
#  ('in', 'a'),
#  ('a', 'real-time'),
#  ('real-time', 'written'),
#  ('written', 'conversation'),
#  ('conversation', 'with'),
#  ('with', 'a'),
#  ('a', 'human'),
#  ('human', 'judge'),
#  ('judge', ','),
#  (',', 'sufficiently'),
#  ('sufficiently', 'well'),
#  ('well', 'that'),
#  ('that', 'the'),
#  ('the', 'judge'),
#  ('judge', 'is'),
#  ('is', 'unable'),
#  ('unable', 'to'),
#  ('to', 'distinguish'),
#  ('distinguish', 'reliably—on'),
#  ('reliably—on', 'the'),
#  ('the', 'basis'),
#  ('basis', 'of'),
#  ('of', 'the'),
#  ('the', 'conversational'),
#  ('conversational', 'content'),
#  ('content', 'alone—between'),
#  ('alone—between', 'the'),
#  ('the', 'program'),
#  ('program', 'and'),
#  ('and', 'a'),
#  ('a', 'real'),
#  ('real', 'human'),
#  ('human', '.'),
#  ('.', 'The'),
#  ('The', 'notoriety'),
#  ('notoriety', 'of'),
#  ('of', 'Turing'),
#  ('Turing', "'s"),
#  ("'s", 'proposed'),
#  ('proposed', 'test'),
#  ('test', 'stimulated'),
#  ('stimulated', 'great'),
#  ('great', 'interest'),
#  ('interest', 'in'),
#  ('in', 'Joseph'),
#  ('Joseph', 'Weizenbaum'),
#  ('Weizenbaum', "'s"),
#  ("'s", 'program'),
#  ('program', 'ELIZA'),
#  ('ELIZA', ','),
#  (',', 'published'),
#  ('published', 'in'),
#  ('in', '1966'),
#  ('1966', ','),
#  (',', 'which'),
#  ('which', 'seemed'),
#  ('seemed', 'to'),
#  ('to', 'be'),
#  ('be', 'able'),
#  ('able', 'to'),
#  ('to', 'fool'),
#  ('fool', 'users'),
#  ('users', 'into'),
#  ('into', 'believing'),
#  ('believing', 'that'),
#  ('that', 'they'),
#  ('they', 'were'),
#  ('were', 'conversing'),
#  ('conversing', 'with'),
#  ('with', 'a'),
#  ('a', 'real'),
#  ('real', 'human'),
#  ('human', '.'),
#  ('.', 'However'),
#  ('However', 'Weizenbaum'),
#  ('Weizenbaum', 'himself'),
#  ('himself', 'did'),
#  ('did', 'not'),
#  ('not', 'claim'),
#  ('claim', 'that'),
#  ('that', 'ELIZA'),
#  ('ELIZA', 'was'),
#  ('was', 'genuinely'),
#  ('genuinely', 'intelligent'),
#  ('intelligent', ','),
#  (',', 'and'),
#  ('and', 'the'),
#  ('the', 'Introduction'),
#  ('Introduction', 'to'),
#  ('to', 'his'),
#  ('his', 'paper'),
#  ('paper', 'presented'),
#  ('presented', 'it'),
#  ('it', 'more'),
#  ('more', 'as'),
#  ('as', 'a'),
#  ('a', 'debunking'),
#  ('debunking', 'exercise'),
#  ('exercise', ':'),
#  (':', '['),
#  ('[', 'In'),
#  ('In', ']'),
#  (']', 'artificial'),
#  ('artificial', 'intelligence'),
#  ('intelligence', '...'),
#  ('...', 'machines'),
#  ('machines', 'are'),
#  ('are', 'made'),
#  ('made', 'to'),
#  ('to', 'behave'),
#  ('behave', 'in'),
#  ('in', 'wondrous'),
#  ('wondrous', 'ways'),
#  ('ways', ','),
#  (',', 'often'),
#  ('often', 'sufficient'),
#  ('sufficient', 'to'),
#  ('to', 'dazzle'),
#  ('dazzle', 'even'),
#  ('even', 'the'),
#  ('the', 'most'),
#  ('most', 'experienced'),
#  ('experienced', 'observer'),
#  ('observer', '.'),
#  ('.', 'But'),
#  ('But', 'once'),
#  ('once', 'a'),
#  ('a', 'particular'),
#  ('particular', 'program'),
#  ('program', 'is'),
#  ('is', 'unmasked'),
#  ('unmasked', ','),
#  (',', 'once'),
#  ('once', 'its'),
#  ('its', 'inner'),
#  ('inner', 'workings'),
#  ('workings', 'are'),
#  ('are', 'explained'),
#  ('explained', '...'),
#  ('...', 'its'),
#  ('its', 'magic'),
#  ('magic', 'crumbles'),
#  ('crumbles', 'away'),
#  ('away', ';'),
#  (';', 'it'),
#  ('it', 'stands'),
#  ('stands', 'revealed'),
#  ('revealed', 'as'),
#  ('as', 'a'),
#  ('a', 'mere'),
#  ('mere', 'collection'),
#  ('collection', 'of'),
#  ('of', 'procedures'),
#  ('procedures', '...'),
#  ('...', 'The'),
#  ('The', 'observer'),
#  ('observer', 'says'),
#  ('says', 'to'),
#  ('to', 'himself'),
#  ('himself', '``'),
#  ('``', 'I'),
#  ('I', 'could'),
#  ('could', 'have'),
#  ('have', 'written'),
#  ('written', 'that'),
#  ('that', "''"),
#  ("''", '.'),
#  ('.', 'With'),
#  ('With', 'that'),
#  ('that', 'thought'),
#  ('thought', 'he'),
#  ('he', 'moves'),
#  ('moves', 'the'),
#  ('the', 'program'),
#  ('program', 'in'),
#  ('in', 'question'),
#  ('question', 'from'),
#  ('from', 'the'),
#  ('the', 'shelf'),
#  ('shelf', 'marked'),
#  ('marked', '``'),
#  ('``', 'intelligent'),
#  ('intelligent', "''"),
#  ("''", ','),
#  (',', 'to'),
#  ('to', 'that'),
#  ('that', 'reserved'),
#  ('reserved', 'for'),
#  ('for', 'curios'),
#  ('curios', '...'),
#  ('...', 'The'),
#  ('The', 'object'),
#  ('object', 'of'),
#  ('of', 'this'),
#  ('this', 'paper'),
#  ('paper', 'is'),
#  ('is', 'to'),
#  ('to', 'cause'),
#  ('cause', 'just'),
#  ('just', 'such'),
#  ('such', 'a'),
#  ('a', 're-evaluation'),
#  ('re-evaluation', 'of'),
#  ('of', 'the'),
#  ('the', 'program'),
#  ('program', 'about'),
#  ('about', 'to'),
#  ('to', 'be'),
#  ('be', '``'),
#  ('``', 'explained'),
#  ('explained', "''"),
#  ("''", '.'),
#  ('.', 'Few'),
#  ('Few', 'programs'),
#  ('programs', 'ever'),
#  ('ever', 'needed'),
#  ('needed', 'it'),
#  ('it', 'more'),
#  ('more', '.'),
#  ('.', 'ELIZA'),
#  ('ELIZA', "'s"),
#  ("'s", 'key'),
#  ('key', 'method'),
#  ('method', 'of'),
#  ('of', 'operation'),
#  ('operation', '('),
#  ('(', 'copied'),
#  ('copied', 'by'),
#  ('by', 'chatbot'),
#  ('chatbot', 'designers'),
#  ('designers', 'ever'),
#  ('ever', 'since'),
#  ('since', ')'),
#  (')', 'involves'),
#  ('involves', 'the'),
#  ('the', 'recognition'),
#  ('recognition', 'of'),
#  ('of', 'cue'),
#  ('cue', 'words'),
#  ('words', 'or'),
#  ('or', 'phrases'),
#  ('phrases', 'in'),
#  ('in', 'the'),
#  ('the', 'input'),
#  ('input', ','),
#  (',', 'and'),
#  ('and', 'the'),
#  ('the', 'output'),
#  ('output', 'of'),
#  ('of', 'corresponding'),
#  ('corresponding', 'pre-prepared'),
#  ('pre-prepared', 'or'),
#  ('or', 'pre-programmed'),
#  ('pre-programmed', 'responses'),
#  ('responses', 'that'),
#  ('that', 'can'),
#  ('can', 'move'),
#  ('move', 'the'),
#  ('the', 'conversation'),
#  ('conversation', 'forward'),
#  ('forward', 'in'),
#  ('in', 'an'),
#  ('an', 'apparently'),
#  ('apparently', 'meaningful'),
#  ('meaningful', 'way'),
#  ('way', '('),
#  ('(', 'e.g'),
#  ('e.g', '.'),
#  ('.', 'by'),
#  ('by', 'responding'),
#  ('responding', 'to'),
#  ('to', 'any'),
#  ('any', 'input'),
#  ('input', 'that'),
#  ('that', 'contains'),
#  ('contains', 'the'),
#  ('the', 'word'),
#  ('word', "'MOTHER"),
#  ("'MOTHER", "'"),
#  ("'", 'with'),
#  ('with', "'TELL"),
#  ("'TELL", 'ME'),
#  ('ME', 'MORE'),
#  ('MORE', 'ABOUT'),
#  ('ABOUT', 'YOUR'),
#  ('YOUR', 'FAMILY'),
#  ('FAMILY', "'"),
#  ("'", ')'),
#  (')', '.Thus'),
#  ('.Thus', 'an'),
#  ('an', 'illusion'),
#  ('illusion', 'of'),
#  ('of', 'understanding'),
#  ('understanding', 'is'),
#  ('is', 'generated'),
#  ('generated', ','),
#  (',', 'even'),
#  ('even', 'though'),
#  ('though', 'the'),
#  ('the', 'processing'),
#  ('processing', 'involved'),
#  ('involved', 'has'),
#  ('has', 'been'),
#  ('been', 'merely'),
#  ('merely', 'superficial'),
#  ('superficial', '.'),
#  ('.', 'ELIZA'),
#  ('ELIZA', 'showed'),
#  ('showed', 'that'),
#  ('that', 'such'),
#  ('such', 'an'),
#  ('an', 'illusion'),
#  ('illusion', 'is'),
#  ('is', 'surprisingly'),
#  ('surprisingly', 'easy'),
#  ('easy', 'to'),
#  ('to', 'generate'),
#  ('generate', ','),
#  (',', 'because'),
#  ('because', 'human'),
#  ('human', 'judges'),
#  ('judges', 'are'),
#  ('are', 'so'),
#  ('so', 'ready'),
#  ('ready', 'to'),
#  ('to', 'give'),
#  ('give', 'the'),
#  ('the', 'benefit'),
#  ('benefit', 'of'),
#  ('of', 'the'),
#  ('the', 'doubt'),
#  ('doubt', 'when'),
#  ('when', 'conversational'),
#  ('conversational', 'responses'),
#  ('responses', 'are'),
#  ('are', 'capable'),
#  ('capable', 'of'),
#  ('of', 'being'),
#  ('being', 'interpreted'),
#  ('interpreted', 'as'),
#  ('as', '``'),
#  ('``', 'intelligent'),
#  ('intelligent', "''"),
#  ("''", '.'),
#  ('.', 'Interface'),
#  ('Interface', 'designers'),
#  ('designers', 'have'),
#  ('have', 'come'),
#  ('come', 'to'),
#  ('to', 'appreciate'),
#  ('appreciate', 'that'),
#  ('that', 'humans'),
#  ('humans', "'"),
#  ("'", 'readiness'),
#  ('readiness', 'to'),
#  ('to', 'interpret'),
#  ('interpret', 'computer'),
#  ('computer', 'output'),
#  ('output', 'as'),
#  ('as', 'genuinely'),
#  ('genuinely', 'conversational—even'),
#  ('conversational—even', 'when'),
#  ('when', 'it'),
#  ('it', 'is'),
#  ('is', 'actually'),
#  ('actually', 'based'),
#  ('based', 'on'),
#  ('on', 'rather'),
#  ('rather', 'simple'),
#  ('simple', 'pattern-matching—can'),
#  ('pattern-matching—can', 'be'),
#  ('be', 'exploited'),
#  ('exploited', 'for'),
#  ('for', 'useful'),
#  ('useful', 'purposes'),
#  ('purposes', '.'),
#  ('.', 'Most'),
#  ('Most', 'people'),
#  ('people', 'prefer'),
#  ('prefer', 'to'),
#  ('to', 'engage'),
#  ('engage', 'with'),
#  ('with', 'programs'),
#  ('programs', 'that'),
#  ('that', 'are'),
#  ('are', 'human-like'),
#  ('human-like', ','),
#  (',', 'and'),
#  ('and', 'this'),
#  ('this', 'gives'),
#  ('gives', 'chatbot-style'),
#  ('chatbot-style', 'techniques'),
#  ('techniques', 'a'),
#  ('a', 'potentially'),
#  ('potentially', 'useful'),
#  ('useful', 'role'),
#  ('role', 'in'),
#  ('in', 'interactive'),
#  ('interactive', 'systems'),
#  ('systems', 'that'),
#  ('that', 'need'),
#  ('need', 'to'),
#  ('to', 'elicit'),
#  ('elicit', 'information'),
#  ('information', 'from'),
#  ('from', 'users'),
#  ('users', ','),
#  (',', 'as'),
#  ('as', 'long'),
#  ('long', 'as'),
#  ('as', 'that'),
#  ('that', 'information'),
#  ('information', 'is'),
#  ('is', 'relatively'),
#  ('relatively', 'straightforward'),
#  ('straightforward', 'and'),
#  ('and', 'falls'),
#  ('falls', 'into'),
#  ('into', 'predictable'),
#  ('predictable', 'categories'),
#  ('categories', '.'),
#  ('.', 'Thus'),
#  ('Thus', ','),
#  (',', 'for'),
#  ('for', 'example'),
#  ('example', ','),
#  (',', 'online'),
#  ('online', 'help'),
#  ('help', 'systems'),
#  ('systems', 'can'),
#  ('can', 'usefully'),
#  ('usefully', 'employ'),
#  ('employ', 'chatbot'),
#  ('chatbot', 'techniques'),
#  ('techniques', 'to'),
#  ('to', 'identify'),
#  ('identify', 'the'),
#  ('the', 'area'),
#  ('area', 'of'),
#  ('of', 'help'),
#  ('help', 'that'),
#  ('that', 'users'),
#  ('users', 'require'),
#  ('require', ','),
#  (',', 'potentially'),
#  ('potentially', 'providing'),
#  ('providing', 'a'),
#  ('a', '``'),
#  ('``', 'friendlier'),
#  ('friendlier', "''"),
#  ("''", 'interface'),
#  ('interface', 'than'),
#  ('than', 'a'),
#  ('a', 'more'),
#  ('more', 'formal'),
#  ('formal', 'search'),
#  ('search', 'or'),
#  ('or', 'menu'),
#  ('menu', 'system'),
#  ('system', '.'),
#  ('.', 'This'),
#  ('This', 'sort'),
#  ('sort', 'of'),
#  ('of', 'usage'),
#  ('usage', 'holds'),
#  ('holds', 'the'),
#  ('the', 'prospect'),
#  ('prospect', 'of'),
#  ('of', 'moving'),
#  ('moving', 'chatbot'),
#  ('chatbot', 'technology'),
#  ('technology', 'from'),
#  ('from', 'Weizenbaum'),
#  ('Weizenbaum', "'s"),
#  ("'s", '``'),
#  ('``', 'shelf'),
#  ('shelf', '...'),
#  ('...', 'reserved'),
#  ('reserved', 'for'),
#  ('for', 'curios'),
#  ('curios', "''"),
#  ("''", 'to'),
#  ('to', 'that'),
#  ('that', 'marked'),
#  ('marked', '``'),
#  ('``', 'genuinely'),
#  ('genuinely', 'useful'),
#  ('useful', 'computational'),
#  ('computational', 'methods'),
#  ('methods', "''"),
#  ("''", '.'),
#  ('.', 'Development'),
#  ('Development', 'The'),
#  ('The', 'classic'),
#  ('classic', 'historic'),
#  ('historic', 'early'),
#  ('early', 'chatbots'),
#  ('chatbots', 'are'),
#  ('are', 'ELIZA'),
#  ('ELIZA', '('),
#  ('(', '1966'),
#  ('1966', ')'),
#  (')', 'and'),
#  ('and', 'PARRY'),
#  ('PARRY', '('),
#  ('(', '1972'),
#  ('1972', ')'),
#  (')', '.More'),
#  ('.More', 'recent'),
#  ('recent', 'notable'),
#  ('notable', 'programs'),
#  ('programs', 'include'),
#  ('include', 'A.L.I.C.E.'),
#  ('A.L.I.C.E.', ','),
#  (',', 'Jabberwacky'),
#  ('Jabberwacky', 'and'),
#  ('and', 'D.U.D.E'),
#  ('D.U.D.E', '('),
#  ('(', 'Agence'),
#  ('Agence', 'Nationale'),
#  ('Nationale', 'de'),
#  ('de', 'la'),
#  ('la', 'Recherche'),
#  ('Recherche', 'and'),
#  ('and', 'CNRS'),
#  ('CNRS', '2006'),
#  ('2006', ')'),
#  (')', '.'),
#  ('.', 'While'),
#  ('While', 'ELIZA'),
#  ('ELIZA', 'and'),
#  ('and', 'PARRY'),
#  ('PARRY', 'were'),
#  ('were', 'used'),
#  ('used', 'exclusively'),
#  ('exclusively', 'to'),
#  ('to', 'simulate'),
#  ('simulate', 'typed'),
#  ('typed', 'conversation'),
#  ('conversation', ','),
#  (',', 'many'),
#  ('many', 'chatbots'),
#  ('chatbots', 'now'),
#  ('now', 'include'),
#  ('include', 'functional'),
#  ('functional', 'features'),
#  ('features', 'such'),
#  ('such', 'as'),
#  ('as', 'games'),
#  ('games', 'and'),
#  ('and', 'web'),
#  ('web', 'searching'),
#  ('searching', 'abilities'),
#  ('abilities', '.'),
#  ('.', 'In'),
#  ('In', '1984'),
#  ('1984', ','),
#  (',', 'a'),
#  ('a', 'book'),
#  ('book', 'called'),
#  ('called', 'The'),
#  ('The', 'Policeman'),
#  ('Policeman', "'s"),
#  ("'s", 'Beard'),
#  ('Beard', 'is'),
#  ('is', 'Half'),
#  ('Half', 'Constructed'),
#  ('Constructed', 'was'),
#  ('was', 'published'),
#  ('published', ','),
#  (',', 'allegedly'),
#  ('allegedly', 'written'),
#  ('written', 'by'),
#  ('by', 'the'),
#  ('the', 'chatbot'),
#  ('chatbot', 'Racter'),
#  ('Racter', '('),
#  ('(', 'though'),
#  ('though', 'the'),
#  ('the', 'program'),
#  ('program', 'as'),
#  ('as', 'released'),
#  ('released', 'would'),
#  ('would', 'not'),
#  ('not', 'have'),
#  ('have', 'been'),
#  ('been', 'capable'),
#  ('capable', 'of'),
#  ('of', 'doing'),
#  ('doing', 'so'),
#  ('so', ')'),
#  (')', '.'),
#  ('.', 'One'),
#  ('One', 'pertinent'),
#  ('pertinent', 'field'),
#  ('field', 'of'),
#  ('of', 'AI'),
#  ('AI', 'research'),
#  ('research', 'is'),
#  ('is', 'natural'),
#  ('natural', 'language'),
#  ('language', 'processing'),
#  ('processing', '.'),
#  ('.', 'Usually'),
#  ('Usually', ','),
#  (',', 'weak'),
#  ('weak', 'AI'),
#  ('AI', 'fields'),
#  ('fields', 'employ'),
#  ('employ', 'specialized'),
#  ('specialized', 'software'),
#  ('software', 'or'),
#  ('or', 'programming'),
#  ('programming', 'languages'),
#  ('languages', 'created'),
#  ('created', 'specifically'),
#  ('specifically', 'for'),
#  ('for', 'the'),
#  ('the', 'narrow'),
#  ('narrow', 'function'),
#  ('function', 'required'),
#  ('required', '.'),
#  ('.', 'For'),
#  ('For', 'example'),
#  ('example', ','),
#  (',', 'A.L.I.C.E'),
#  ('A.L.I.C.E', '.'),
#  ('.', 'uses'),
#  ('uses', 'a'),
#  ('a', 'markup'),
#  ('markup', 'language'),
#  ('language', 'called'),
#  ('called', 'AIML'),
#  ('AIML', ','),
#  (',', 'which'),
#  ('which', 'is'),
#  ('is', 'specific'),
#  ('specific', 'to'),
#  ('to', 'its'),
#  ('its', 'function'),
#  ('function', 'as'),
#  ('as', 'a'),
#  ('a', 'conversational'),
#  ('conversational', 'agent'),
#  ('agent', ','),
#  (',', 'and'),
#  ('and', 'has'),
#  ('has', 'since'),
#  ('since', 'been'),
#  ('been', 'adopted'),
#  ('adopted', 'by'),
#  ('by', 'various'),
#  ('various', 'other'),
#  ('other', 'developers'),
#  ('developers', 'of'),
#  ('of', ','),
#  (',', 'so'),
#  ('so', 'called'),
#  ('called', ','),
#  (',', 'Alicebots'),
#  ('Alicebots', '.'),
#  ('.', 'Nevertheless'),
#  ('Nevertheless', ','),
#  (',', 'A.L.I.C.E'),
#  ('A.L.I.C.E', '.'),
#  ('.', 'is'),
#  ('is', 'still'),
#  ('still', 'purely'),
#  ('purely', 'based'),
#  ('based', 'on'),
#  ('on', 'pattern'),
#  ('pattern', 'matching'),
#  ('matching', 'techniques'),
#  ('techniques', 'without'),
#  ('without', 'any'),
#  ('any', 'reasoning'),
#  ('reasoning', 'capabilities'),
#  ('capabilities', ','),
#  (',', 'the'),
#  ('the', 'same'),
#  ('same', 'technique'),
#  ('technique', 'ELIZA'),
#  ('ELIZA', 'was'),
#  ('was', 'using'),
#  ('using', 'back'),
#  ('back', 'in'),
#  ('in', '1966'),
#  ('1966', '.'),
#  ('.', 'This'),
#  ('This', 'is'),
#  ('is', 'not'),
#  ('not', 'strong'),
#  ('strong', 'AI'),
#  ('AI', ','),
#  (',', 'which'),
#  ('which', 'would'),
#  ('would', 'require'),
#  ('require', 'sapience'),
#  ('sapience', 'and'),
#  ('and', 'logical'),
#  ('logical', 'reasoning'),
#  ('reasoning', 'abilities'),
#  ('abilities', '.'),
#  ('.', 'Jabberwacky'),
#  ...]

# %%
quotes_trigrams=list(nltk.trigrams(quotes_tokens))
quotes_trigrams
# Out:
# [('A', 'chatbot', '('),
#  ('chatbot', '(', 'also'),
#  ('(', 'also', 'known'),
#  ('also', 'known', 'as'),
#  ('known', 'as', 'a'),
#  ('as', 'a', 'talkbot'),
#  ('a', 'talkbot', ','),
#  ('talkbot', ',', 'chatterbot'),
#  (',', 'chatterbot', ','),
#  ('chatterbot', ',', 'Bot'),
#  (',', 'Bot', ','),
#  ('Bot', ',', 'IM'),
#  (',', 'IM', 'bot'),
#  ('IM', 'bot', ','),
#  ('bot', ',', 'interactive'),
#  (',', 'interactive', 'agent'),
#  ('interactive', 'agent', ','),
#  ('agent', ',', 'or'),
#  (',', 'or', 'Artificial'),
#  ('or', 'Artificial', 'Conversational'),
#  ('Artificial', 'Conversational', 'Entity'),
#  ('Conversational', 'Entity', ')'),
#  ('Entity', ')', 'is'),
#  (')', 'is', 'a'),
#  ('is', 'a', 'computer'),
#  ('a', 'computer', 'program'),
#  ('computer', 'program', 'or'),
#  ('program', 'or', 'an'),
#  ('or', 'an', 'artificial'),
#  ('an', 'artificial', 'intelligence'),
#  ('artificial', 'intelligence', 'which'),
#  ('intelligence', 'which', 'conducts'),
#  ('which', 'conducts', 'a'),
#  ('conducts', 'a', 'conversation'),
#  ('a', 'conversation', 'via'),
#  ('conversation', 'via', 'auditory'),
#  ('via', 'auditory', 'or'),
#  ('auditory', 'or', 'textual'),
#  ('or', 'textual', 'methods'),
#  ('textual', 'methods', '.'),
#  ('methods', '.', 'Such'),
#  ('.', 'Such', 'programs'),
#  ('Such', 'programs', 'are'),
#  ('programs', 'are', 'often'),
#  ('are', 'often', 'designed'),
#  ('often', 'designed', 'to'),
#  ('designed', 'to', 'convincingly'),
#  ('to', 'convincingly', 'simulate'),
#  ('convincingly', 'simulate', 'how'),
#  ('simulate', 'how', 'a'),
#  ('how', 'a', 'human'),
#  ('a', 'human', 'would'),
#  ('human', 'would', 'behave'),
#  ('would', 'behave', 'as'),
#  ('behave', 'as', 'a'),
#  ('as', 'a', 'conversational'),
#  ('a', 'conversational', 'partner'),
#  ('conversational', 'partner', ','),
#  ('partner', ',', 'thereby'),
#  (',', 'thereby', 'passing'),
#  ('thereby', 'passing', 'the'),
#  ('passing', 'the', 'Turing'),
#  ('the', 'Turing', 'test'),
#  ('Turing', 'test', '.'),
#  ('test', '.', 'Chatbots'),
#  ('.', 'Chatbots', 'are'),
#  ('Chatbots', 'are', 'typically'),
#  ('are', 'typically', 'used'),
#  ('typically', 'used', 'in'),
#  ('used', 'in', 'dialog'),
#  ('in', 'dialog', 'systems'),
#  ('dialog', 'systems', 'for'),
#  ('systems', 'for', 'various'),
#  ('for', 'various', 'practical'),
#  ('various', 'practical', 'purposes'),
#  ('practical', 'purposes', 'including'),
#  ('purposes', 'including', 'customer'),
#  ('including', 'customer', 'service'),
#  ('customer', 'service', 'or'),
#  ('service', 'or', 'information'),
#  ('or', 'information', 'acquisition'),
#  ('information', 'acquisition', '.'),
#  ('acquisition', '.', 'Some'),
#  ('.', 'Some', 'chatterbots'),
#  ('Some', 'chatterbots', 'use'),
#  ('chatterbots', 'use', 'sophisticated'),
#  ('use', 'sophisticated', 'natural'),
#  ('sophisticated', 'natural', 'language'),
#  ('natural', 'language', 'processing'),
#  ('language', 'processing', 'systems'),
#  ('processing', 'systems', ','),
#  ('systems', ',', 'but'),
#  (',', 'but', 'many'),
#  ('but', 'many', 'simpler'),
#  ('many', 'simpler', 'systems'),
#  ('simpler', 'systems', 'scan'),
#  ('systems', 'scan', 'for'),
#  ('scan', 'for', 'keywords'),
#  ('for', 'keywords', 'within'),
#  ('keywords', 'within', 'the'),
#  ('within', 'the', 'input'),
#  ('the', 'input', ','),
#  ('input', ',', 'then'),
#  (',', 'then', 'pull'),
#  ('then', 'pull', 'a'),
#  ('pull', 'a', 'reply'),
#  ('a', 'reply', 'with'),
#  ('reply', 'with', 'the'),
#  ('with', 'the', 'most'),
#  ('the', 'most', 'matching'),
#  ('most', 'matching', 'keywords'),
#  ('matching', 'keywords', ','),
#  ('keywords', ',', 'or'),
#  (',', 'or', 'the'),
#  ('or', 'the', 'most'),
#  ('the', 'most', 'similar'),
#  ('most', 'similar', 'wording'),
#  ('similar', 'wording', 'pattern'),
#  ('wording', 'pattern', ','),
#  ('pattern', ',', 'from'),
#  (',', 'from', 'a'),
#  ('from', 'a', 'database'),
#  ('a', 'database', '.'),
#  ('database', '.', 'The'),
#  ('.', 'The', 'term'),
#  ('The', 'term', '``'),
#  ('term', '``', 'ChatterBot'),
#  ('``', 'ChatterBot', "''"),
#  ('ChatterBot', "''", 'was'),
#  ("''", 'was', 'originally'),
#  ('was', 'originally', 'coined'),
#  ('originally', 'coined', 'by'),
#  ('coined', 'by', 'Michael'),
#  ('by', 'Michael', 'Mauldin'),
#  ('Michael', 'Mauldin', '('),
#  ('Mauldin', '(', 'creator'),
#  ('(', 'creator', 'of'),
#  ('creator', 'of', 'the'),
#  ('of', 'the', 'first'),
#  ('the', 'first', 'Verbot'),
#  ('first', 'Verbot', ','),
#  ('Verbot', ',', 'Julia'),
#  (',', 'Julia', ')'),
#  ('Julia', ')', 'in'),
#  (')', 'in', '1994'),
#  ('in', '1994', 'to'),
#  ('1994', 'to', 'describe'),
#  ('to', 'describe', 'these'),
#  ('describe', 'these', 'conversational'),
#  ('these', 'conversational', 'programs.Today'),
#  ('conversational', 'programs.Today', ','),
#  ('programs.Today', ',', 'most'),
#  (',', 'most', 'chatbots'),
#  ('most', 'chatbots', 'are'),
#  ('chatbots', 'are', 'either'),
#  ('are', 'either', 'accessed'),
#  ('either', 'accessed', 'via'),
#  ('accessed', 'via', 'virtual'),
#  ('via', 'virtual', 'assistants'),
#  ('virtual', 'assistants', 'such'),
#  ('assistants', 'such', 'as'),
#  ('such', 'as', 'Google'),
#  ('as', 'Google', 'Assistant'),
#  ('Google', 'Assistant', 'and'),
#  ('Assistant', 'and', 'Amazon'),
#  ('and', 'Amazon', 'Alexa'),
#  ('Amazon', 'Alexa', ','),
#  ('Alexa', ',', 'via'),
#  (',', 'via', 'messaging'),
#  ('via', 'messaging', 'apps'),
#  ('messaging', 'apps', 'such'),
#  ('apps', 'such', 'as'),
#  ('such', 'as', 'Facebook'),
#  ('as', 'Facebook', 'Messenger'),
#  ('Facebook', 'Messenger', 'or'),
#  ('Messenger', 'or', 'WeChat'),
#  ('or', 'WeChat', ','),
#  ('WeChat', ',', 'or'),
#  (',', 'or', 'via'),
#  ('or', 'via', 'individual'),
#  ('via', 'individual', 'organizations'),
#  ('individual', 'organizations', "'"),
#  ('organizations', "'", 'apps'),
#  ("'", 'apps', 'and'),
#  ('apps', 'and', 'websites'),
#  ('and', 'websites', '.'),
#  ('websites', '.', 'Chatbots'),
#  ('.', 'Chatbots', 'can'),
#  ('Chatbots', 'can', 'be'),
#  ('can', 'be', 'classified'),
#  ('be', 'classified', 'into'),
#  ('classified', 'into', 'usage'),
#  ('into', 'usage', 'categories'),
#  ('usage', 'categories', 'such'),
#  ('categories', 'such', 'as'),
#  ('such', 'as', 'conversational'),
#  ('as', 'conversational', 'commerce'),
#  ('conversational', 'commerce', '('),
#  ('commerce', '(', 'e-commerce'),
#  ('(', 'e-commerce', 'via'),
#  ('e-commerce', 'via', 'chat'),
#  ('via', 'chat', ')'),
#  ('chat', ')', ','),
#  (')', ',', 'analytics'),
#  (',', 'analytics', ','),
#  ('analytics', ',', 'communication'),
#  (',', 'communication', ','),
#  ('communication', ',', 'customer'),
#  (',', 'customer', 'support'),
#  ('customer', 'support', ','),
#  ('support', ',', 'design'),
#  (',', 'design', ','),
#  ('design', ',', 'developer'),
#  (',', 'developer', 'tools'),
#  ('developer', 'tools', ','),
#  ('tools', ',', 'education'),
#  (',', 'education', ','),
#  ('education', ',', 'entertainment'),
#  (',', 'entertainment', ','),
#  ('entertainment', ',', 'finance'),
#  (',', 'finance', ','),
#  ('finance', ',', 'food'),
#  (',', 'food', ','),
#  ('food', ',', 'games'),
#  (',', 'games', ','),
#  ('games', ',', 'health'),
#  (',', 'health', ','),
#  ('health', ',', 'HR'),
#  (',', 'HR', ','),
#  ('HR', ',', 'marketing'),
#  (',', 'marketing', ','),
#  ('marketing', ',', 'news'),
#  (',', 'news', ','),
#  ('news', ',', 'personal'),
#  (',', 'personal', ','),
#  ('personal', ',', 'productivity'),
#  (',', 'productivity', ','),
#  ('productivity', ',', 'shopping'),
#  (',', 'shopping', ','),
#  ('shopping', ',', 'social'),
#  (',', 'social', ','),
#  ('social', ',', 'sports'),
#  (',', 'sports', ','),
#  ('sports', ',', 'travel'),
#  (',', 'travel', 'and'),
#  ('travel', 'and', 'utilities'),
#  ('and', 'utilities', '.'),
#  ('utilities', '.', 'Background'),
#  ('.', 'Background', 'In'),
#  ('Background', 'In', '1950'),
#  ('In', '1950', ','),
#  ('1950', ',', 'Alan'),
#  (',', 'Alan', 'Turing'),
#  ('Alan', 'Turing', "'s"),
#  ('Turing', "'s", 'famous'),
#  ("'s", 'famous', 'article'),
#  ('famous', 'article', '``'),
#  ('article', '``', 'Computing'),
#  ('``', 'Computing', 'Machinery'),
#  ('Computing', 'Machinery', 'and'),
#  ('Machinery', 'and', 'Intelligence'),
#  ('and', 'Intelligence', "''"),
#  ('Intelligence', "''", 'was'),
#  ("''", 'was', 'published'),
#  ('was', 'published', ','),
#  ('published', ',', 'which'),
#  (',', 'which', 'proposed'),
#  ('which', 'proposed', 'what'),
#  ('proposed', 'what', 'is'),
#  ('what', 'is', 'now'),
#  ('is', 'now', 'called'),
#  ('now', 'called', 'the'),
#  ('called', 'the', 'Turing'),
#  ('the', 'Turing', 'test'),
#  ('Turing', 'test', 'as'),
#  ('test', 'as', 'a'),
#  ('as', 'a', 'criterion'),
#  ('a', 'criterion', 'of'),
#  ('criterion', 'of', 'intelligence'),
#  ('of', 'intelligence', '.'),
#  ('intelligence', '.', 'This'),
#  ('.', 'This', 'criterion'),
#  ('This', 'criterion', 'depends'),
#  ('criterion', 'depends', 'on'),
#  ('depends', 'on', 'the'),
#  ('on', 'the', 'ability'),
#  ('the', 'ability', 'of'),
#  ('ability', 'of', 'a'),
#  ('of', 'a', 'computer'),
#  ('a', 'computer', 'program'),
#  ('computer', 'program', 'to'),
#  ('program', 'to', 'impersonate'),
#  ('to', 'impersonate', 'a'),
#  ('impersonate', 'a', 'human'),
#  ('a', 'human', 'in'),
#  ('human', 'in', 'a'),
#  ('in', 'a', 'real-time'),
#  ('a', 'real-time', 'written'),
#  ('real-time', 'written', 'conversation'),
#  ('written', 'conversation', 'with'),
#  ('conversation', 'with', 'a'),
#  ('with', 'a', 'human'),
#  ('a', 'human', 'judge'),
#  ('human', 'judge', ','),
#  ('judge', ',', 'sufficiently'),
#  (',', 'sufficiently', 'well'),
#  ('sufficiently', 'well', 'that'),
#  ('well', 'that', 'the'),
#  ('that', 'the', 'judge'),
#  ('the', 'judge', 'is'),
#  ('judge', 'is', 'unable'),
#  ('is', 'unable', 'to'),
#  ('unable', 'to', 'distinguish'),
#  ('to', 'distinguish', 'reliably—on'),
#  ('distinguish', 'reliably—on', 'the'),
#  ('reliably—on', 'the', 'basis'),
#  ('the', 'basis', 'of'),
#  ('basis', 'of', 'the'),
#  ('of', 'the', 'conversational'),
#  ('the', 'conversational', 'content'),
#  ('conversational', 'content', 'alone—between'),
#  ('content', 'alone—between', 'the'),
#  ('alone—between', 'the', 'program'),
#  ('the', 'program', 'and'),
#  ('program', 'and', 'a'),
#  ('and', 'a', 'real'),
#  ('a', 'real', 'human'),
#  ('real', 'human', '.'),
#  ('human', '.', 'The'),
#  ('.', 'The', 'notoriety'),
#  ('The', 'notoriety', 'of'),
#  ('notoriety', 'of', 'Turing'),
#  ('of', 'Turing', "'s"),
#  ('Turing', "'s", 'proposed'),
#  ("'s", 'proposed', 'test'),
#  ('proposed', 'test', 'stimulated'),
#  ('test', 'stimulated', 'great'),
#  ('stimulated', 'great', 'interest'),
#  ('great', 'interest', 'in'),
#  ('interest', 'in', 'Joseph'),
#  ('in', 'Joseph', 'Weizenbaum'),
#  ('Joseph', 'Weizenbaum', "'s"),
#  ('Weizenbaum', "'s", 'program'),
#  ("'s", 'program', 'ELIZA'),
#  ('program', 'ELIZA', ','),
#  ('ELIZA', ',', 'published'),
#  (',', 'published', 'in'),
#  ('published', 'in', '1966'),
#  ('in', '1966', ','),
#  ('1966', ',', 'which'),
#  (',', 'which', 'seemed'),
#  ('which', 'seemed', 'to'),
#  ('seemed', 'to', 'be'),
#  ('to', 'be', 'able'),
#  ('be', 'able', 'to'),
#  ('able', 'to', 'fool'),
#  ('to', 'fool', 'users'),
#  ('fool', 'users', 'into'),
#  ('users', 'into', 'believing'),
#  ('into', 'believing', 'that'),
#  ('believing', 'that', 'they'),
#  ('that', 'they', 'were'),
#  ('they', 'were', 'conversing'),
#  ('were', 'conversing', 'with'),
#  ('conversing', 'with', 'a'),
#  ('with', 'a', 'real'),
#  ('a', 'real', 'human'),
#  ('real', 'human', '.'),
#  ('human', '.', 'However'),
#  ('.', 'However', 'Weizenbaum'),
#  ('However', 'Weizenbaum', 'himself'),
#  ('Weizenbaum', 'himself', 'did'),
#  ('himself', 'did', 'not'),
#  ('did', 'not', 'claim'),
#  ('not', 'claim', 'that'),
#  ('claim', 'that', 'ELIZA'),
#  ('that', 'ELIZA', 'was'),
#  ('ELIZA', 'was', 'genuinely'),
#  ('was', 'genuinely', 'intelligent'),
#  ('genuinely', 'intelligent', ','),
#  ('intelligent', ',', 'and'),
#  (',', 'and', 'the'),
#  ('and', 'the', 'Introduction'),
#  ('the', 'Introduction', 'to'),
#  ('Introduction', 'to', 'his'),
#  ('to', 'his', 'paper'),
#  ('his', 'paper', 'presented'),
#  ('paper', 'presented', 'it'),
#  ('presented', 'it', 'more'),
#  ('it', 'more', 'as'),
#  ('more', 'as', 'a'),
#  ('as', 'a', 'debunking'),
#  ('a', 'debunking', 'exercise'),
#  ('debunking', 'exercise', ':'),
#  ('exercise', ':', '['),
#  (':', '[', 'In'),
#  ('[', 'In', ']'),
#  ('In', ']', 'artificial'),
#  (']', 'artificial', 'intelligence'),
#  ('artificial', 'intelligence', '...'),
#  ('intelligence', '...', 'machines'),
#  ('...', 'machines', 'are'),
#  ('machines', 'are', 'made'),
#  ('are', 'made', 'to'),
#  ('made', 'to', 'behave'),
#  ('to', 'behave', 'in'),
#  ('behave', 'in', 'wondrous'),
#  ('in', 'wondrous', 'ways'),
#  ('wondrous', 'ways', ','),
#  ('ways', ',', 'often'),
#  (',', 'often', 'sufficient'),
#  ('often', 'sufficient', 'to'),
#  ('sufficient', 'to', 'dazzle'),
#  ('to', 'dazzle', 'even'),
#  ('dazzle', 'even', 'the'),
#  ('even', 'the', 'most'),
#  ('the', 'most', 'experienced'),
#  ('most', 'experienced', 'observer'),
#  ('experienced', 'observer', '.'),
#  ('observer', '.', 'But'),
#  ('.', 'But', 'once'),
#  ('But', 'once', 'a'),
#  ('once', 'a', 'particular'),
#  ('a', 'particular', 'program'),
#  ('particular', 'program', 'is'),
#  ('program', 'is', 'unmasked'),
#  ('is', 'unmasked', ','),
#  ('unmasked', ',', 'once'),
#  (',', 'once', 'its'),
#  ('once', 'its', 'inner'),
#  ('its', 'inner', 'workings'),
#  ('inner', 'workings', 'are'),
#  ('workings', 'are', 'explained'),
#  ('are', 'explained', '...'),
#  ('explained', '...', 'its'),
#  ('...', 'its', 'magic'),
#  ('its', 'magic', 'crumbles'),
#  ('magic', 'crumbles', 'away'),
#  ('crumbles', 'away', ';'),
#  ('away', ';', 'it'),
#  (';', 'it', 'stands'),
#  ('it', 'stands', 'revealed'),
#  ('stands', 'revealed', 'as'),
#  ('revealed', 'as', 'a'),
#  ('as', 'a', 'mere'),
#  ('a', 'mere', 'collection'),
#  ('mere', 'collection', 'of'),
#  ('collection', 'of', 'procedures'),
#  ('of', 'procedures', '...'),
#  ('procedures', '...', 'The'),
#  ('...', 'The', 'observer'),
#  ('The', 'observer', 'says'),
#  ('observer', 'says', 'to'),
#  ('says', 'to', 'himself'),
#  ('to', 'himself', '``'),
#  ('himself', '``', 'I'),
#  ('``', 'I', 'could'),
#  ('I', 'could', 'have'),
#  ('could', 'have', 'written'),
#  ('have', 'written', 'that'),
#  ('written', 'that', "''"),
#  ('that', "''", '.'),
#  ("''", '.', 'With'),
#  ('.', 'With', 'that'),
#  ('With', 'that', 'thought'),
#  ('that', 'thought', 'he'),
#  ('thought', 'he', 'moves'),
#  ('he', 'moves', 'the'),
#  ('moves', 'the', 'program'),
#  ('the', 'program', 'in'),
#  ('program', 'in', 'question'),
#  ('in', 'question', 'from'),
#  ('question', 'from', 'the'),
#  ('from', 'the', 'shelf'),
#  ('the', 'shelf', 'marked'),
#  ('shelf', 'marked', '``'),
#  ('marked', '``', 'intelligent'),
#  ('``', 'intelligent', "''"),
#  ('intelligent', "''", ','),
#  ("''", ',', 'to'),
#  (',', 'to', 'that'),
#  ('to', 'that', 'reserved'),
#  ('that', 'reserved', 'for'),
#  ('reserved', 'for', 'curios'),
#  ('for', 'curios', '...'),
#  ('curios', '...', 'The'),
#  ('...', 'The', 'object'),
#  ('The', 'object', 'of'),
#  ('object', 'of', 'this'),
#  ('of', 'this', 'paper'),
#  ('this', 'paper', 'is'),
#  ('paper', 'is', 'to'),
#  ('is', 'to', 'cause'),
#  ('to', 'cause', 'just'),
#  ('cause', 'just', 'such'),
#  ('just', 'such', 'a'),
#  ('such', 'a', 're-evaluation'),
#  ('a', 're-evaluation', 'of'),
#  ('re-evaluation', 'of', 'the'),
#  ('of', 'the', 'program'),
#  ('the', 'program', 'about'),
#  ('program', 'about', 'to'),
#  ('about', 'to', 'be'),
#  ('to', 'be', '``'),
#  ('be', '``', 'explained'),
#  ('``', 'explained', "''"),
#  ('explained', "''", '.'),
#  ("''", '.', 'Few'),
#  ('.', 'Few', 'programs'),
#  ('Few', 'programs', 'ever'),
#  ('programs', 'ever', 'needed'),
#  ('ever', 'needed', 'it'),
#  ('needed', 'it', 'more'),
#  ('it', 'more', '.'),
#  ('more', '.', 'ELIZA'),
#  ('.', 'ELIZA', "'s"),
#  ('ELIZA', "'s", 'key'),
#  ("'s", 'key', 'method'),
#  ('key', 'method', 'of'),
#  ('method', 'of', 'operation'),
#  ('of', 'operation', '('),
#  ('operation', '(', 'copied'),
#  ('(', 'copied', 'by'),
#  ('copied', 'by', 'chatbot'),
#  ('by', 'chatbot', 'designers'),
#  ('chatbot', 'designers', 'ever'),
#  ('designers', 'ever', 'since'),
#  ('ever', 'since', ')'),
#  ('since', ')', 'involves'),
#  (')', 'involves', 'the'),
#  ('involves', 'the', 'recognition'),
#  ('the', 'recognition', 'of'),
#  ('recognition', 'of', 'cue'),
#  ('of', 'cue', 'words'),
#  ('cue', 'words', 'or'),
#  ('words', 'or', 'phrases'),
#  ('or', 'phrases', 'in'),
#  ('phrases', 'in', 'the'),
#  ('in', 'the', 'input'),
#  ('the', 'input', ','),
#  ('input', ',', 'and'),
#  (',', 'and', 'the'),
#  ('and', 'the', 'output'),
#  ('the', 'output', 'of'),
#  ('output', 'of', 'corresponding'),
#  ('of', 'corresponding', 'pre-prepared'),
#  ('corresponding', 'pre-prepared', 'or'),
#  ('pre-prepared', 'or', 'pre-programmed'),
#  ('or', 'pre-programmed', 'responses'),
#  ('pre-programmed', 'responses', 'that'),
#  ('responses', 'that', 'can'),
#  ('that', 'can', 'move'),
#  ('can', 'move', 'the'),
#  ('move', 'the', 'conversation'),
#  ('the', 'conversation', 'forward'),
#  ('conversation', 'forward', 'in'),
#  ('forward', 'in', 'an'),
#  ('in', 'an', 'apparently'),
#  ('an', 'apparently', 'meaningful'),
#  ('apparently', 'meaningful', 'way'),
#  ('meaningful', 'way', '('),
#  ('way', '(', 'e.g'),
#  ('(', 'e.g', '.'),
#  ('e.g', '.', 'by'),
#  ('.', 'by', 'responding'),
#  ('by', 'responding', 'to'),
#  ('responding', 'to', 'any'),
#  ('to', 'any', 'input'),
#  ('any', 'input', 'that'),
#  ('input', 'that', 'contains'),
#  ('that', 'contains', 'the'),
#  ('contains', 'the', 'word'),
#  ('the', 'word', "'MOTHER"),
#  ('word', "'MOTHER", "'"),
#  ("'MOTHER", "'", 'with'),
#  ("'", 'with', "'TELL"),
#  ('with', "'TELL", 'ME'),
#  ("'TELL", 'ME', 'MORE'),
#  ('ME', 'MORE', 'ABOUT'),
#  ('MORE', 'ABOUT', 'YOUR'),
#  ('ABOUT', 'YOUR', 'FAMILY'),
#  ('YOUR', 'FAMILY', "'"),
#  ('FAMILY', "'", ')'),
#  ("'", ')', '.Thus'),
#  (')', '.Thus', 'an'),
#  ('.Thus', 'an', 'illusion'),
#  ('an', 'illusion', 'of'),
#  ('illusion', 'of', 'understanding'),
#  ('of', 'understanding', 'is'),
#  ('understanding', 'is', 'generated'),
#  ('is', 'generated', ','),
#  ('generated', ',', 'even'),
#  (',', 'even', 'though'),
#  ('even', 'though', 'the'),
#  ('though', 'the', 'processing'),
#  ('the', 'processing', 'involved'),
#  ('processing', 'involved', 'has'),
#  ('involved', 'has', 'been'),
#  ('has', 'been', 'merely'),
#  ('been', 'merely', 'superficial'),
#  ('merely', 'superficial', '.'),
#  ('superficial', '.', 'ELIZA'),
#  ('.', 'ELIZA', 'showed'),
#  ('ELIZA', 'showed', 'that'),
#  ('showed', 'that', 'such'),
#  ('that', 'such', 'an'),
#  ('such', 'an', 'illusion'),
#  ('an', 'illusion', 'is'),
#  ('illusion', 'is', 'surprisingly'),
#  ('is', 'surprisingly', 'easy'),
#  ('surprisingly', 'easy', 'to'),
#  ('easy', 'to', 'generate'),
#  ('to', 'generate', ','),
#  ('generate', ',', 'because'),
#  (',', 'because', 'human'),
#  ('because', 'human', 'judges'),
#  ('human', 'judges', 'are'),
#  ('judges', 'are', 'so'),
#  ('are', 'so', 'ready'),
#  ('so', 'ready', 'to'),
#  ('ready', 'to', 'give'),
#  ('to', 'give', 'the'),
#  ('give', 'the', 'benefit'),
#  ('the', 'benefit', 'of'),
#  ('benefit', 'of', 'the'),
#  ('of', 'the', 'doubt'),
#  ('the', 'doubt', 'when'),
#  ('doubt', 'when', 'conversational'),
#  ('when', 'conversational', 'responses'),
#  ('conversational', 'responses', 'are'),
#  ('responses', 'are', 'capable'),
#  ('are', 'capable', 'of'),
#  ('capable', 'of', 'being'),
#  ('of', 'being', 'interpreted'),
#  ('being', 'interpreted', 'as'),
#  ('interpreted', 'as', '``'),
#  ('as', '``', 'intelligent'),
#  ('``', 'intelligent', "''"),
#  ('intelligent', "''", '.'),
#  ("''", '.', 'Interface'),
#  ('.', 'Interface', 'designers'),
#  ('Interface', 'designers', 'have'),
#  ('designers', 'have', 'come'),
#  ('have', 'come', 'to'),
#  ('come', 'to', 'appreciate'),
#  ('to', 'appreciate', 'that'),
#  ('appreciate', 'that', 'humans'),
#  ('that', 'humans', "'"),
#  ('humans', "'", 'readiness'),
#  ("'", 'readiness', 'to'),
#  ('readiness', 'to', 'interpret'),
#  ('to', 'interpret', 'computer'),
#  ('interpret', 'computer', 'output'),
#  ('computer', 'output', 'as'),
#  ('output', 'as', 'genuinely'),
#  ('as', 'genuinely', 'conversational—even'),
#  ('genuinely', 'conversational—even', 'when'),
#  ('conversational—even', 'when', 'it'),
#  ('when', 'it', 'is'),
#  ('it', 'is', 'actually'),
#  ('is', 'actually', 'based'),
#  ('actually', 'based', 'on'),
#  ('based', 'on', 'rather'),
#  ('on', 'rather', 'simple'),
#  ('rather', 'simple', 'pattern-matching—can'),
#  ('simple', 'pattern-matching—can', 'be'),
#  ('pattern-matching—can', 'be', 'exploited'),
#  ('be', 'exploited', 'for'),
#  ('exploited', 'for', 'useful'),
#  ('for', 'useful', 'purposes'),
#  ('useful', 'purposes', '.'),
#  ('purposes', '.', 'Most'),
#  ('.', 'Most', 'people'),
#  ('Most', 'people', 'prefer'),
#  ('people', 'prefer', 'to'),
#  ('prefer', 'to', 'engage'),
#  ('to', 'engage', 'with'),
#  ('engage', 'with', 'programs'),
#  ('with', 'programs', 'that'),
#  ('programs', 'that', 'are'),
#  ('that', 'are', 'human-like'),
#  ('are', 'human-like', ','),
#  ('human-like', ',', 'and'),
#  (',', 'and', 'this'),
#  ('and', 'this', 'gives'),
#  ('this', 'gives', 'chatbot-style'),
#  ('gives', 'chatbot-style', 'techniques'),
#  ('chatbot-style', 'techniques', 'a'),
#  ('techniques', 'a', 'potentially'),
#  ('a', 'potentially', 'useful'),
#  ('potentially', 'useful', 'role'),
#  ('useful', 'role', 'in'),
#  ('role', 'in', 'interactive'),
#  ('in', 'interactive', 'systems'),
#  ('interactive', 'systems', 'that'),
#  ('systems', 'that', 'need'),
#  ('that', 'need', 'to'),
#  ('need', 'to', 'elicit'),
#  ('to', 'elicit', 'information'),
#  ('elicit', 'information', 'from'),
#  ('information', 'from', 'users'),
#  ('from', 'users', ','),
#  ('users', ',', 'as'),
#  (',', 'as', 'long'),
#  ('as', 'long', 'as'),
#  ('long', 'as', 'that'),
#  ('as', 'that', 'information'),
#  ('that', 'information', 'is'),
#  ('information', 'is', 'relatively'),
#  ('is', 'relatively', 'straightforward'),
#  ('relatively', 'straightforward', 'and'),
#  ('straightforward', 'and', 'falls'),
#  ('and', 'falls', 'into'),
#  ('falls', 'into', 'predictable'),
#  ('into', 'predictable', 'categories'),
#  ('predictable', 'categories', '.'),
#  ('categories', '.', 'Thus'),
#  ('.', 'Thus', ','),
#  ('Thus', ',', 'for'),
#  (',', 'for', 'example'),
#  ('for', 'example', ','),
#  ('example', ',', 'online'),
#  (',', 'online', 'help'),
#  ('online', 'help', 'systems'),
#  ('help', 'systems', 'can'),
#  ('systems', 'can', 'usefully'),
#  ('can', 'usefully', 'employ'),
#  ('usefully', 'employ', 'chatbot'),
#  ('employ', 'chatbot', 'techniques'),
#  ('chatbot', 'techniques', 'to'),
#  ('techniques', 'to', 'identify'),
#  ('to', 'identify', 'the'),
#  ('identify', 'the', 'area'),
#  ('the', 'area', 'of'),
#  ('area', 'of', 'help'),
#  ('of', 'help', 'that'),
#  ('help', 'that', 'users'),
#  ('that', 'users', 'require'),
#  ('users', 'require', ','),
#  ('require', ',', 'potentially'),
#  (',', 'potentially', 'providing'),
#  ('potentially', 'providing', 'a'),
#  ('providing', 'a', '``'),
#  ('a', '``', 'friendlier'),
#  ('``', 'friendlier', "''"),
#  ('friendlier', "''", 'interface'),
#  ("''", 'interface', 'than'),
#  ('interface', 'than', 'a'),
#  ('than', 'a', 'more'),
#  ('a', 'more', 'formal'),
#  ('more', 'formal', 'search'),
#  ('formal', 'search', 'or'),
#  ('search', 'or', 'menu'),
#  ('or', 'menu', 'system'),
#  ('menu', 'system', '.'),
#  ('system', '.', 'This'),
#  ('.', 'This', 'sort'),
#  ('This', 'sort', 'of'),
#  ('sort', 'of', 'usage'),
#  ('of', 'usage', 'holds'),
#  ('usage', 'holds', 'the'),
#  ('holds', 'the', 'prospect'),
#  ('the', 'prospect', 'of'),
#  ('prospect', 'of', 'moving'),
#  ('of', 'moving', 'chatbot'),
#  ('moving', 'chatbot', 'technology'),
#  ('chatbot', 'technology', 'from'),
#  ('technology', 'from', 'Weizenbaum'),
#  ('from', 'Weizenbaum', "'s"),
#  ('Weizenbaum', "'s", '``'),
#  ("'s", '``', 'shelf'),
#  ('``', 'shelf', '...'),
#  ('shelf', '...', 'reserved'),
#  ('...', 'reserved', 'for'),
#  ('reserved', 'for', 'curios'),
#  ('for', 'curios', "''"),
#  ('curios', "''", 'to'),
#  ("''", 'to', 'that'),
#  ('to', 'that', 'marked'),
#  ('that', 'marked', '``'),
#  ('marked', '``', 'genuinely'),
#  ('``', 'genuinely', 'useful'),
#  ('genuinely', 'useful', 'computational'),
#  ('useful', 'computational', 'methods'),
#  ('computational', 'methods', "''"),
#  ('methods', "''", '.'),
#  ("''", '.', 'Development'),
#  ('.', 'Development', 'The'),
#  ('Development', 'The', 'classic'),
#  ('The', 'classic', 'historic'),
#  ('classic', 'historic', 'early'),
#  ('historic', 'early', 'chatbots'),
#  ('early', 'chatbots', 'are'),
#  ('chatbots', 'are', 'ELIZA'),
#  ('are', 'ELIZA', '('),
#  ('ELIZA', '(', '1966'),
#  ('(', '1966', ')'),
#  ('1966', ')', 'and'),
#  (')', 'and', 'PARRY'),
#  ('and', 'PARRY', '('),
#  ('PARRY', '(', '1972'),
#  ('(', '1972', ')'),
#  ('1972', ')', '.More'),
#  (')', '.More', 'recent'),
#  ('.More', 'recent', 'notable'),
#  ('recent', 'notable', 'programs'),
#  ('notable', 'programs', 'include'),
#  ('programs', 'include', 'A.L.I.C.E.'),
#  ('include', 'A.L.I.C.E.', ','),
#  ('A.L.I.C.E.', ',', 'Jabberwacky'),
#  (',', 'Jabberwacky', 'and'),
#  ('Jabberwacky', 'and', 'D.U.D.E'),
#  ('and', 'D.U.D.E', '('),
#  ('D.U.D.E', '(', 'Agence'),
#  ('(', 'Agence', 'Nationale'),
#  ('Agence', 'Nationale', 'de'),
#  ('Nationale', 'de', 'la'),
#  ('de', 'la', 'Recherche'),
#  ('la', 'Recherche', 'and'),
#  ('Recherche', 'and', 'CNRS'),
#  ('and', 'CNRS', '2006'),
#  ('CNRS', '2006', ')'),
#  ('2006', ')', '.'),
#  (')', '.', 'While'),
#  ('.', 'While', 'ELIZA'),
#  ('While', 'ELIZA', 'and'),
#  ('ELIZA', 'and', 'PARRY'),
#  ('and', 'PARRY', 'were'),
#  ('PARRY', 'were', 'used'),
#  ('were', 'used', 'exclusively'),
#  ('used', 'exclusively', 'to'),
#  ('exclusively', 'to', 'simulate'),
#  ('to', 'simulate', 'typed'),
#  ('simulate', 'typed', 'conversation'),
#  ('typed', 'conversation', ','),
#  ('conversation', ',', 'many'),
#  (',', 'many', 'chatbots'),
#  ('many', 'chatbots', 'now'),
#  ('chatbots', 'now', 'include'),
#  ('now', 'include', 'functional'),
#  ('include', 'functional', 'features'),
#  ('functional', 'features', 'such'),
#  ('features', 'such', 'as'),
#  ('such', 'as', 'games'),
#  ('as', 'games', 'and'),
#  ('games', 'and', 'web'),
#  ('and', 'web', 'searching'),
#  ('web', 'searching', 'abilities'),
#  ('searching', 'abilities', '.'),
#  ('abilities', '.', 'In'),
#  ('.', 'In', '1984'),
#  ('In', '1984', ','),
#  ('1984', ',', 'a'),
#  (',', 'a', 'book'),
#  ('a', 'book', 'called'),
#  ('book', 'called', 'The'),
#  ('called', 'The', 'Policeman'),
#  ('The', 'Policeman', "'s"),
#  ('Policeman', "'s", 'Beard'),
#  ("'s", 'Beard', 'is'),
#  ('Beard', 'is', 'Half'),
#  ('is', 'Half', 'Constructed'),
#  ('Half', 'Constructed', 'was'),
#  ('Constructed', 'was', 'published'),
#  ('was', 'published', ','),
#  ('published', ',', 'allegedly'),
#  (',', 'allegedly', 'written'),
#  ('allegedly', 'written', 'by'),
#  ('written', 'by', 'the'),
#  ('by', 'the', 'chatbot'),
#  ('the', 'chatbot', 'Racter'),
#  ('chatbot', 'Racter', '('),
#  ('Racter', '(', 'though'),
#  ('(', 'though', 'the'),
#  ('though', 'the', 'program'),
#  ('the', 'program', 'as'),
#  ('program', 'as', 'released'),
#  ('as', 'released', 'would'),
#  ('released', 'would', 'not'),
#  ('would', 'not', 'have'),
#  ('not', 'have', 'been'),
#  ('have', 'been', 'capable'),
#  ('been', 'capable', 'of'),
#  ('capable', 'of', 'doing'),
#  ('of', 'doing', 'so'),
#  ('doing', 'so', ')'),
#  ('so', ')', '.'),
#  (')', '.', 'One'),
#  ('.', 'One', 'pertinent'),
#  ('One', 'pertinent', 'field'),
#  ('pertinent', 'field', 'of'),
#  ('field', 'of', 'AI'),
#  ('of', 'AI', 'research'),
#  ('AI', 'research', 'is'),
#  ('research', 'is', 'natural'),
#  ('is', 'natural', 'language'),
#  ('natural', 'language', 'processing'),
#  ('language', 'processing', '.'),
#  ('processing', '.', 'Usually'),
#  ('.', 'Usually', ','),
#  ('Usually', ',', 'weak'),
#  (',', 'weak', 'AI'),
#  ('weak', 'AI', 'fields'),
#  ('AI', 'fields', 'employ'),
#  ('fields', 'employ', 'specialized'),
#  ('employ', 'specialized', 'software'),
#  ('specialized', 'software', 'or'),
#  ('software', 'or', 'programming'),
#  ('or', 'programming', 'languages'),
#  ('programming', 'languages', 'created'),
#  ('languages', 'created', 'specifically'),
#  ('created', 'specifically', 'for'),
#  ('specifically', 'for', 'the'),
#  ('for', 'the', 'narrow'),
#  ('the', 'narrow', 'function'),
#  ('narrow', 'function', 'required'),
#  ('function', 'required', '.'),
#  ('required', '.', 'For'),
#  ('.', 'For', 'example'),
#  ('For', 'example', ','),
#  ('example', ',', 'A.L.I.C.E'),
#  (',', 'A.L.I.C.E', '.'),
#  ('A.L.I.C.E', '.', 'uses'),
#  ('.', 'uses', 'a'),
#  ('uses', 'a', 'markup'),
#  ('a', 'markup', 'language'),
#  ('markup', 'language', 'called'),
#  ('language', 'called', 'AIML'),
#  ('called', 'AIML', ','),
#  ('AIML', ',', 'which'),
#  (',', 'which', 'is'),
#  ('which', 'is', 'specific'),
#  ('is', 'specific', 'to'),
#  ('specific', 'to', 'its'),
#  ('to', 'its', 'function'),
#  ('its', 'function', 'as'),
#  ('function', 'as', 'a'),
#  ('as', 'a', 'conversational'),
#  ('a', 'conversational', 'agent'),
#  ('conversational', 'agent', ','),
#  ('agent', ',', 'and'),
#  (',', 'and', 'has'),
#  ('and', 'has', 'since'),
#  ('has', 'since', 'been'),
#  ('since', 'been', 'adopted'),
#  ('been', 'adopted', 'by'),
#  ('adopted', 'by', 'various'),
#  ('by', 'various', 'other'),
#  ('various', 'other', 'developers'),
#  ('other', 'developers', 'of'),
#  ('developers', 'of', ','),
#  ('of', ',', 'so'),
#  (',', 'so', 'called'),
#  ('so', 'called', ','),
#  ('called', ',', 'Alicebots'),
#  (',', 'Alicebots', '.'),
#  ('Alicebots', '.', 'Nevertheless'),
#  ('.', 'Nevertheless', ','),
#  ('Nevertheless', ',', 'A.L.I.C.E'),
#  (',', 'A.L.I.C.E', '.'),
#  ('A.L.I.C.E', '.', 'is'),
#  ('.', 'is', 'still'),
#  ('is', 'still', 'purely'),
#  ('still', 'purely', 'based'),
#  ('purely', 'based', 'on'),
#  ('based', 'on', 'pattern'),
#  ('on', 'pattern', 'matching'),
#  ('pattern', 'matching', 'techniques'),
#  ('matching', 'techniques', 'without'),
#  ('techniques', 'without', 'any'),
#  ('without', 'any', 'reasoning'),
#  ('any', 'reasoning', 'capabilities'),
#  ('reasoning', 'capabilities', ','),
#  ('capabilities', ',', 'the'),
#  (',', 'the', 'same'),
#  ('the', 'same', 'technique'),
#  ('same', 'technique', 'ELIZA'),
#  ('technique', 'ELIZA', 'was'),
#  ('ELIZA', 'was', 'using'),
#  ('was', 'using', 'back'),
#  ('using', 'back', 'in'),
#  ('back', 'in', '1966'),
#  ('in', '1966', '.'),
#  ('1966', '.', 'This'),
#  ('.', 'This', 'is'),
#  ('This', 'is', 'not'),
#  ('is', 'not', 'strong'),
#  ('not', 'strong', 'AI'),
#  ('strong', 'AI', ','),
#  ('AI', ',', 'which'),
#  (',', 'which', 'would'),
#  ('which', 'would', 'require'),
#  ('would', 'require', 'sapience'),
#  ('require', 'sapience', 'and'),
#  ('sapience', 'and', 'logical'),
#  ('and', 'logical', 'reasoning'),
#  ('logical', 'reasoning', 'abilities'),
#  ('reasoning', 'abilities', '.'),
#  ('abilities', '.', 'Jabberwacky'),
#  ('.', 'Jabberwacky', 'learns'),
#  ...]

# %%
quotes_ngrams=list(nltk.ngrams(quotes_tokens,4))
quotes_ngrams
# Out:
# [('A', 'chatbot', '(', 'also'),
#  ('chatbot', '(', 'also', 'known'),
#  ('(', 'also', 'known', 'as'),
#  ('also', 'known', 'as', 'a'),
#  ('known', 'as', 'a', 'talkbot'),
#  ('as', 'a', 'talkbot', ','),
#  ('a', 'talkbot', ',', 'chatterbot'),
#  ('talkbot', ',', 'chatterbot', ','),
#  (',', 'chatterbot', ',', 'Bot'),
#  ('chatterbot', ',', 'Bot', ','),
#  (',', 'Bot', ',', 'IM'),
#  ('Bot', ',', 'IM', 'bot'),
#  (',', 'IM', 'bot', ','),
#  ('IM', 'bot', ',', 'interactive'),
#  ('bot', ',', 'interactive', 'agent'),
#  (',', 'interactive', 'agent', ','),
#  ('interactive', 'agent', ',', 'or'),
#  ('agent', ',', 'or', 'Artificial'),
#  (',', 'or', 'Artificial', 'Conversational'),
#  ('or', 'Artificial', 'Conversational', 'Entity'),
#  ('Artificial', 'Conversational', 'Entity', ')'),
#  ('Conversational', 'Entity', ')', 'is'),
#  ('Entity', ')', 'is', 'a'),
#  (')', 'is', 'a', 'computer'),
#  ('is', 'a', 'computer', 'program'),
#  ('a', 'computer', 'program', 'or'),
#  ('computer', 'program', 'or', 'an'),
#  ('program', 'or', 'an', 'artificial'),
#  ('or', 'an', 'artificial', 'intelligence'),
#  ('an', 'artificial', 'intelligence', 'which'),
#  ('artificial', 'intelligence', 'which', 'conducts'),
#  ('intelligence', 'which', 'conducts', 'a'),
#  ('which', 'conducts', 'a', 'conversation'),
#  ('conducts', 'a', 'conversation', 'via'),
#  ('a', 'conversation', 'via', 'auditory'),
#  ('conversation', 'via', 'auditory', 'or'),
#  ('via', 'auditory', 'or', 'textual'),
#  ('auditory', 'or', 'textual', 'methods'),
#  ('or', 'textual', 'methods', '.'),
#  ('textual', 'methods', '.', 'Such'),
#  ('methods', '.', 'Such', 'programs'),
#  ('.', 'Such', 'programs', 'are'),
#  ('Such', 'programs', 'are', 'often'),
#  ('programs', 'are', 'often', 'designed'),
#  ('are', 'often', 'designed', 'to'),
#  ('often', 'designed', 'to', 'convincingly'),
#  ('designed', 'to', 'convincingly', 'simulate'),
#  ('to', 'convincingly', 'simulate', 'how'),
#  ('convincingly', 'simulate', 'how', 'a'),
#  ('simulate', 'how', 'a', 'human'),
#  ('how', 'a', 'human', 'would'),
#  ('a', 'human', 'would', 'behave'),
#  ('human', 'would', 'behave', 'as'),
#  ('would', 'behave', 'as', 'a'),
#  ('behave', 'as', 'a', 'conversational'),
#  ('as', 'a', 'conversational', 'partner'),
#  ('a', 'conversational', 'partner', ','),
#  ('conversational', 'partner', ',', 'thereby'),
#  ('partner', ',', 'thereby', 'passing'),
#  (',', 'thereby', 'passing', 'the'),
#  ('thereby', 'passing', 'the', 'Turing'),
#  ('passing', 'the', 'Turing', 'test'),
#  ('the', 'Turing', 'test', '.'),
#  ('Turing', 'test', '.', 'Chatbots'),
#  ('test', '.', 'Chatbots', 'are'),
#  ('.', 'Chatbots', 'are', 'typically'),
#  ('Chatbots', 'are', 'typically', 'used'),
#  ('are', 'typically', 'used', 'in'),
#  ('typically', 'used', 'in', 'dialog'),
#  ('used', 'in', 'dialog', 'systems'),
#  ('in', 'dialog', 'systems', 'for'),
#  ('dialog', 'systems', 'for', 'various'),
#  ('systems', 'for', 'various', 'practical'),
#  ('for', 'various', 'practical', 'purposes'),
#  ('various', 'practical', 'purposes', 'including'),
#  ('practical', 'purposes', 'including', 'customer'),
#  ('purposes', 'including', 'customer', 'service'),
#  ('including', 'customer', 'service', 'or'),
#  ('customer', 'service', 'or', 'information'),
#  ('service', 'or', 'information', 'acquisition'),
#  ('or', 'information', 'acquisition', '.'),
#  ('information', 'acquisition', '.', 'Some'),
#  ('acquisition', '.', 'Some', 'chatterbots'),
#  ('.', 'Some', 'chatterbots', 'use'),
#  ('Some', 'chatterbots', 'use', 'sophisticated'),
#  ('chatterbots', 'use', 'sophisticated', 'natural'),
#  ('use', 'sophisticated', 'natural', 'language'),
#  ('sophisticated', 'natural', 'language', 'processing'),
#  ('natural', 'language', 'processing', 'systems'),
#  ('language', 'processing', 'systems', ','),
#  ('processing', 'systems', ',', 'but'),
#  ('systems', ',', 'but', 'many'),
#  (',', 'but', 'many', 'simpler'),
#  ('but', 'many', 'simpler', 'systems'),
#  ('many', 'simpler', 'systems', 'scan'),
#  ('simpler', 'systems', 'scan', 'for'),
#  ('systems', 'scan', 'for', 'keywords'),
#  ('scan', 'for', 'keywords', 'within'),
#  ('for', 'keywords', 'within', 'the'),
#  ('keywords', 'within', 'the', 'input'),
#  ('within', 'the', 'input', ','),
#  ('the', 'input', ',', 'then'),
#  ('input', ',', 'then', 'pull'),
#  (',', 'then', 'pull', 'a'),
#  ('then', 'pull', 'a', 'reply'),
#  ('pull', 'a', 'reply', 'with'),
#  ('a', 'reply', 'with', 'the'),
#  ('reply', 'with', 'the', 'most'),
#  ('with', 'the', 'most', 'matching'),
#  ('the', 'most', 'matching', 'keywords'),
#  ('most', 'matching', 'keywords', ','),
#  ('matching', 'keywords', ',', 'or'),
#  ('keywords', ',', 'or', 'the'),
#  (',', 'or', 'the', 'most'),
#  ('or', 'the', 'most', 'similar'),
#  ('the', 'most', 'similar', 'wording'),
#  ('most', 'similar', 'wording', 'pattern'),
#  ('similar', 'wording', 'pattern', ','),
#  ('wording', 'pattern', ',', 'from'),
#  ('pattern', ',', 'from', 'a'),
#  (',', 'from', 'a', 'database'),
#  ('from', 'a', 'database', '.'),
#  ('a', 'database', '.', 'The'),
#  ('database', '.', 'The', 'term'),
#  ('.', 'The', 'term', '``'),
#  ('The', 'term', '``', 'ChatterBot'),
#  ('term', '``', 'ChatterBot', "''"),
#  ('``', 'ChatterBot', "''", 'was'),
#  ('ChatterBot', "''", 'was', 'originally'),
#  ("''", 'was', 'originally', 'coined'),
#  ('was', 'originally', 'coined', 'by'),
#  ('originally', 'coined', 'by', 'Michael'),
#  ('coined', 'by', 'Michael', 'Mauldin'),
#  ('by', 'Michael', 'Mauldin', '('),
#  ('Michael', 'Mauldin', '(', 'creator'),
#  ('Mauldin', '(', 'creator', 'of'),
#  ('(', 'creator', 'of', 'the'),
#  ('creator', 'of', 'the', 'first'),
#  ('of', 'the', 'first', 'Verbot'),
#  ('the', 'first', 'Verbot', ','),
#  ('first', 'Verbot', ',', 'Julia'),
#  ('Verbot', ',', 'Julia', ')'),
#  (',', 'Julia', ')', 'in'),
#  ('Julia', ')', 'in', '1994'),
#  (')', 'in', '1994', 'to'),
#  ('in', '1994', 'to', 'describe'),
#  ('1994', 'to', 'describe', 'these'),
#  ('to', 'describe', 'these', 'conversational'),
#  ('describe', 'these', 'conversational', 'programs.Today'),
#  ('these', 'conversational', 'programs.Today', ','),
#  ('conversational', 'programs.Today', ',', 'most'),
#  ('programs.Today', ',', 'most', 'chatbots'),
#  (',', 'most', 'chatbots', 'are'),
#  ('most', 'chatbots', 'are', 'either'),
#  ('chatbots', 'are', 'either', 'accessed'),
#  ('are', 'either', 'accessed', 'via'),
#  ('either', 'accessed', 'via', 'virtual'),
#  ('accessed', 'via', 'virtual', 'assistants'),
#  ('via', 'virtual', 'assistants', 'such'),
#  ('virtual', 'assistants', 'such', 'as'),
#  ('assistants', 'such', 'as', 'Google'),
#  ('such', 'as', 'Google', 'Assistant'),
#  ('as', 'Google', 'Assistant', 'and'),
#  ('Google', 'Assistant', 'and', 'Amazon'),
#  ('Assistant', 'and', 'Amazon', 'Alexa'),
#  ('and', 'Amazon', 'Alexa', ','),
#  ('Amazon', 'Alexa', ',', 'via'),
#  ('Alexa', ',', 'via', 'messaging'),
#  (',', 'via', 'messaging', 'apps'),
#  ('via', 'messaging', 'apps', 'such'),
#  ('messaging', 'apps', 'such', 'as'),
#  ('apps', 'such', 'as', 'Facebook'),
#  ('such', 'as', 'Facebook', 'Messenger'),
#  ('as', 'Facebook', 'Messenger', 'or'),
#  ('Facebook', 'Messenger', 'or', 'WeChat'),
#  ('Messenger', 'or', 'WeChat', ','),
#  ('or', 'WeChat', ',', 'or'),
#  ('WeChat', ',', 'or', 'via'),
#  (',', 'or', 'via', 'individual'),
#  ('or', 'via', 'individual', 'organizations'),
#  ('via', 'individual', 'organizations', "'"),
#  ('individual', 'organizations', "'", 'apps'),
#  ('organizations', "'", 'apps', 'and'),
#  ("'", 'apps', 'and', 'websites'),
#  ('apps', 'and', 'websites', '.'),
#  ('and', 'websites', '.', 'Chatbots'),
#  ('websites', '.', 'Chatbots', 'can'),
#  ('.', 'Chatbots', 'can', 'be'),
#  ('Chatbots', 'can', 'be', 'classified'),
#  ('can', 'be', 'classified', 'into'),
#  ('be', 'classified', 'into', 'usage'),
#  ('classified', 'into', 'usage', 'categories'),
#  ('into', 'usage', 'categories', 'such'),
#  ('usage', 'categories', 'such', 'as'),
#  ('categories', 'such', 'as', 'conversational'),
#  ('such', 'as', 'conversational', 'commerce'),
#  ('as', 'conversational', 'commerce', '('),
#  ('conversational', 'commerce', '(', 'e-commerce'),
#  ('commerce', '(', 'e-commerce', 'via'),
#  ('(', 'e-commerce', 'via', 'chat'),
#  ('e-commerce', 'via', 'chat', ')'),
#  ('via', 'chat', ')', ','),
#  ('chat', ')', ',', 'analytics'),
#  (')', ',', 'analytics', ','),
#  (',', 'analytics', ',', 'communication'),
#  ('analytics', ',', 'communication', ','),
#  (',', 'communication', ',', 'customer'),
#  ('communication', ',', 'customer', 'support'),
#  (',', 'customer', 'support', ','),
#  ('customer', 'support', ',', 'design'),
#  ('support', ',', 'design', ','),
#  (',', 'design', ',', 'developer'),
#  ('design', ',', 'developer', 'tools'),
#  (',', 'developer', 'tools', ','),
#  ('developer', 'tools', ',', 'education'),
#  ('tools', ',', 'education', ','),
#  (',', 'education', ',', 'entertainment'),
#  ('education', ',', 'entertainment', ','),
#  (',', 'entertainment', ',', 'finance'),
#  ('entertainment', ',', 'finance', ','),
#  (',', 'finance', ',', 'food'),
#  ('finance', ',', 'food', ','),
#  (',', 'food', ',', 'games'),
#  ('food', ',', 'games', ','),
#  (',', 'games', ',', 'health'),
#  ('games', ',', 'health', ','),
#  (',', 'health', ',', 'HR'),
#  ('health', ',', 'HR', ','),
#  (',', 'HR', ',', 'marketing'),
#  ('HR', ',', 'marketing', ','),
#  (',', 'marketing', ',', 'news'),
#  ('marketing', ',', 'news', ','),
#  (',', 'news', ',', 'personal'),
#  ('news', ',', 'personal', ','),
#  (',', 'personal', ',', 'productivity'),
#  ('personal', ',', 'productivity', ','),
#  (',', 'productivity', ',', 'shopping'),
#  ('productivity', ',', 'shopping', ','),
#  (',', 'shopping', ',', 'social'),
#  ('shopping', ',', 'social', ','),
#  (',', 'social', ',', 'sports'),
#  ('social', ',', 'sports', ','),
#  (',', 'sports', ',', 'travel'),
#  ('sports', ',', 'travel', 'and'),
#  (',', 'travel', 'and', 'utilities'),
#  ('travel', 'and', 'utilities', '.'),
#  ('and', 'utilities', '.', 'Background'),
#  ('utilities', '.', 'Background', 'In'),
#  ('.', 'Background', 'In', '1950'),
#  ('Background', 'In', '1950', ','),
#  ('In', '1950', ',', 'Alan'),
#  ('1950', ',', 'Alan', 'Turing'),
#  (',', 'Alan', 'Turing', "'s"),
#  ('Alan', 'Turing', "'s", 'famous'),
#  ('Turing', "'s", 'famous', 'article'),
#  ("'s", 'famous', 'article', '``'),
#  ('famous', 'article', '``', 'Computing'),
#  ('article', '``', 'Computing', 'Machinery'),
#  ('``', 'Computing', 'Machinery', 'and'),
#  ('Computing', 'Machinery', 'and', 'Intelligence'),
#  ('Machinery', 'and', 'Intelligence', "''"),
#  ('and', 'Intelligence', "''", 'was'),
#  ('Intelligence', "''", 'was', 'published'),
#  ("''", 'was', 'published', ','),
#  ('was', 'published', ',', 'which'),
#  ('published', ',', 'which', 'proposed'),
#  (',', 'which', 'proposed', 'what'),
#  ('which', 'proposed', 'what', 'is'),
#  ('proposed', 'what', 'is', 'now'),
#  ('what', 'is', 'now', 'called'),
#  ('is', 'now', 'called', 'the'),
#  ('now', 'called', 'the', 'Turing'),
#  ('called', 'the', 'Turing', 'test'),
#  ('the', 'Turing', 'test', 'as'),
#  ('Turing', 'test', 'as', 'a'),
#  ('test', 'as', 'a', 'criterion'),
#  ('as', 'a', 'criterion', 'of'),
#  ('a', 'criterion', 'of', 'intelligence'),
#  ('criterion', 'of', 'intelligence', '.'),
#  ('of', 'intelligence', '.', 'This'),
#  ('intelligence', '.', 'This', 'criterion'),
#  ('.', 'This', 'criterion', 'depends'),
#  ('This', 'criterion', 'depends', 'on'),
#  ('criterion', 'depends', 'on', 'the'),
#  ('depends', 'on', 'the', 'ability'),
#  ('on', 'the', 'ability', 'of'),
#  ('the', 'ability', 'of', 'a'),
#  ('ability', 'of', 'a', 'computer'),
#  ('of', 'a', 'computer', 'program'),
#  ('a', 'computer', 'program', 'to'),
#  ('computer', 'program', 'to', 'impersonate'),
#  ('program', 'to', 'impersonate', 'a'),
#  ('to', 'impersonate', 'a', 'human'),
#  ('impersonate', 'a', 'human', 'in'),
#  ('a', 'human', 'in', 'a'),
#  ('human', 'in', 'a', 'real-time'),
#  ('in', 'a', 'real-time', 'written'),
#  ('a', 'real-time', 'written', 'conversation'),
#  ('real-time', 'written', 'conversation', 'with'),
#  ('written', 'conversation', 'with', 'a'),
#  ('conversation', 'with', 'a', 'human'),
#  ('with', 'a', 'human', 'judge'),
#  ('a', 'human', 'judge', ','),
#  ('human', 'judge', ',', 'sufficiently'),
#  ('judge', ',', 'sufficiently', 'well'),
#  (',', 'sufficiently', 'well', 'that'),
#  ('sufficiently', 'well', 'that', 'the'),
#  ('well', 'that', 'the', 'judge'),
#  ('that', 'the', 'judge', 'is'),
#  ('the', 'judge', 'is', 'unable'),
#  ('judge', 'is', 'unable', 'to'),
#  ('is', 'unable', 'to', 'distinguish'),
#  ('unable', 'to', 'distinguish', 'reliably—on'),
#  ('to', 'distinguish', 'reliably—on', 'the'),
#  ('distinguish', 'reliably—on', 'the', 'basis'),
#  ('reliably—on', 'the', 'basis', 'of'),
#  ('the', 'basis', 'of', 'the'),
#  ('basis', 'of', 'the', 'conversational'),
#  ('of', 'the', 'conversational', 'content'),
#  ('the', 'conversational', 'content', 'alone—between'),
#  ('conversational', 'content', 'alone—between', 'the'),
#  ('content', 'alone—between', 'the', 'program'),
#  ('alone—between', 'the', 'program', 'and'),
#  ('the', 'program', 'and', 'a'),
#  ('program', 'and', 'a', 'real'),
#  ('and', 'a', 'real', 'human'),
#  ('a', 'real', 'human', '.'),
#  ('real', 'human', '.', 'The'),
#  ('human', '.', 'The', 'notoriety'),
#  ('.', 'The', 'notoriety', 'of'),
#  ('The', 'notoriety', 'of', 'Turing'),
#  ('notoriety', 'of', 'Turing', "'s"),
#  ('of', 'Turing', "'s", 'proposed'),
#  ('Turing', "'s", 'proposed', 'test'),
#  ("'s", 'proposed', 'test', 'stimulated'),
#  ('proposed', 'test', 'stimulated', 'great'),
#  ('test', 'stimulated', 'great', 'interest'),
#  ('stimulated', 'great', 'interest', 'in'),
#  ('great', 'interest', 'in', 'Joseph'),
#  ('interest', 'in', 'Joseph', 'Weizenbaum'),
#  ('in', 'Joseph', 'Weizenbaum', "'s"),
#  ('Joseph', 'Weizenbaum', "'s", 'program'),
#  ('Weizenbaum', "'s", 'program', 'ELIZA'),
#  ("'s", 'program', 'ELIZA', ','),
#  ('program', 'ELIZA', ',', 'published'),
#  ('ELIZA', ',', 'published', 'in'),
#  (',', 'published', 'in', '1966'),
#  ('published', 'in', '1966', ','),
#  ('in', '1966', ',', 'which'),
#  ('1966', ',', 'which', 'seemed'),
#  (',', 'which', 'seemed', 'to'),
#  ('which', 'seemed', 'to', 'be'),
#  ('seemed', 'to', 'be', 'able'),
#  ('to', 'be', 'able', 'to'),
#  ('be', 'able', 'to', 'fool'),
#  ('able', 'to', 'fool', 'users'),
#  ('to', 'fool', 'users', 'into'),
#  ('fool', 'users', 'into', 'believing'),
#  ('users', 'into', 'believing', 'that'),
#  ('into', 'believing', 'that', 'they'),
#  ('believing', 'that', 'they', 'were'),
#  ('that', 'they', 'were', 'conversing'),
#  ('they', 'were', 'conversing', 'with'),
#  ('were', 'conversing', 'with', 'a'),
#  ('conversing', 'with', 'a', 'real'),
#  ('with', 'a', 'real', 'human'),
#  ('a', 'real', 'human', '.'),
#  ('real', 'human', '.', 'However'),
#  ('human', '.', 'However', 'Weizenbaum'),
#  ('.', 'However', 'Weizenbaum', 'himself'),
#  ('However', 'Weizenbaum', 'himself', 'did'),
#  ('Weizenbaum', 'himself', 'did', 'not'),
#  ('himself', 'did', 'not', 'claim'),
#  ('did', 'not', 'claim', 'that'),
#  ('not', 'claim', 'that', 'ELIZA'),
#  ('claim', 'that', 'ELIZA', 'was'),
#  ('that', 'ELIZA', 'was', 'genuinely'),
#  ('ELIZA', 'was', 'genuinely', 'intelligent'),
#  ('was', 'genuinely', 'intelligent', ','),
#  ('genuinely', 'intelligent', ',', 'and'),
#  ('intelligent', ',', 'and', 'the'),
#  (',', 'and', 'the', 'Introduction'),
#  ('and', 'the', 'Introduction', 'to'),
#  ('the', 'Introduction', 'to', 'his'),
#  ('Introduction', 'to', 'his', 'paper'),
#  ('to', 'his', 'paper', 'presented'),
#  ('his', 'paper', 'presented', 'it'),
#  ('paper', 'presented', 'it', 'more'),
#  ('presented', 'it', 'more', 'as'),
#  ('it', 'more', 'as', 'a'),
#  ('more', 'as', 'a', 'debunking'),
#  ('as', 'a', 'debunking', 'exercise'),
#  ('a', 'debunking', 'exercise', ':'),
#  ('debunking', 'exercise', ':', '['),
#  ('exercise', ':', '[', 'In'),
#  (':', '[', 'In', ']'),
#  ('[', 'In', ']', 'artificial'),
#  ('In', ']', 'artificial', 'intelligence'),
#  (']', 'artificial', 'intelligence', '...'),
#  ('artificial', 'intelligence', '...', 'machines'),
#  ('intelligence', '...', 'machines', 'are'),
#  ('...', 'machines', 'are', 'made'),
#  ('machines', 'are', 'made', 'to'),
#  ('are', 'made', 'to', 'behave'),
#  ('made', 'to', 'behave', 'in'),
#  ('to', 'behave', 'in', 'wondrous'),
#  ('behave', 'in', 'wondrous', 'ways'),
#  ('in', 'wondrous', 'ways', ','),
#  ('wondrous', 'ways', ',', 'often'),
#  ('ways', ',', 'often', 'sufficient'),
#  (',', 'often', 'sufficient', 'to'),
#  ('often', 'sufficient', 'to', 'dazzle'),
#  ('sufficient', 'to', 'dazzle', 'even'),
#  ('to', 'dazzle', 'even', 'the'),
#  ('dazzle', 'even', 'the', 'most'),
#  ('even', 'the', 'most', 'experienced'),
#  ('the', 'most', 'experienced', 'observer'),
#  ('most', 'experienced', 'observer', '.'),
#  ('experienced', 'observer', '.', 'But'),
#  ('observer', '.', 'But', 'once'),
#  ('.', 'But', 'once', 'a'),
#  ('But', 'once', 'a', 'particular'),
#  ('once', 'a', 'particular', 'program'),
#  ('a', 'particular', 'program', 'is'),
#  ('particular', 'program', 'is', 'unmasked'),
#  ('program', 'is', 'unmasked', ','),
#  ('is', 'unmasked', ',', 'once'),
#  ('unmasked', ',', 'once', 'its'),
#  (',', 'once', 'its', 'inner'),
#  ('once', 'its', 'inner', 'workings'),
#  ('its', 'inner', 'workings', 'are'),
#  ('inner', 'workings', 'are', 'explained'),
#  ('workings', 'are', 'explained', '...'),
#  ('are', 'explained', '...', 'its'),
#  ('explained', '...', 'its', 'magic'),
#  ('...', 'its', 'magic', 'crumbles'),
#  ('its', 'magic', 'crumbles', 'away'),
#  ('magic', 'crumbles', 'away', ';'),
#  ('crumbles', 'away', ';', 'it'),
#  ('away', ';', 'it', 'stands'),
#  (';', 'it', 'stands', 'revealed'),
#  ('it', 'stands', 'revealed', 'as'),
#  ('stands', 'revealed', 'as', 'a'),
#  ('revealed', 'as', 'a', 'mere'),
#  ('as', 'a', 'mere', 'collection'),
#  ('a', 'mere', 'collection', 'of'),
#  ('mere', 'collection', 'of', 'procedures'),
#  ('collection', 'of', 'procedures', '...'),
#  ('of', 'procedures', '...', 'The'),
#  ('procedures', '...', 'The', 'observer'),
#  ('...', 'The', 'observer', 'says'),
#  ('The', 'observer', 'says', 'to'),
#  ('observer', 'says', 'to', 'himself'),
#  ('says', 'to', 'himself', '``'),
#  ('to', 'himself', '``', 'I'),
#  ('himself', '``', 'I', 'could'),
#  ('``', 'I', 'could', 'have'),
#  ('I', 'could', 'have', 'written'),
#  ('could', 'have', 'written', 'that'),
#  ('have', 'written', 'that', "''"),
#  ('written', 'that', "''", '.'),
#  ('that', "''", '.', 'With'),
#  ("''", '.', 'With', 'that'),
#  ('.', 'With', 'that', 'thought'),
#  ('With', 'that', 'thought', 'he'),
#  ('that', 'thought', 'he', 'moves'),
#  ('thought', 'he', 'moves', 'the'),
#  ('he', 'moves', 'the', 'program'),
#  ('moves', 'the', 'program', 'in'),
#  ('the', 'program', 'in', 'question'),
#  ('program', 'in', 'question', 'from'),
#  ('in', 'question', 'from', 'the'),
#  ('question', 'from', 'the', 'shelf'),
#  ('from', 'the', 'shelf', 'marked'),
#  ('the', 'shelf', 'marked', '``'),
#  ('shelf', 'marked', '``', 'intelligent'),
#  ('marked', '``', 'intelligent', "''"),
#  ('``', 'intelligent', "''", ','),
#  ('intelligent', "''", ',', 'to'),
#  ("''", ',', 'to', 'that'),
#  (',', 'to', 'that', 'reserved'),
#  ('to', 'that', 'reserved', 'for'),
#  ('that', 'reserved', 'for', 'curios'),
#  ('reserved', 'for', 'curios', '...'),
#  ('for', 'curios', '...', 'The'),
#  ('curios', '...', 'The', 'object'),
#  ('...', 'The', 'object', 'of'),
#  ('The', 'object', 'of', 'this'),
#  ('object', 'of', 'this', 'paper'),
#  ('of', 'this', 'paper', 'is'),
#  ('this', 'paper', 'is', 'to'),
#  ('paper', 'is', 'to', 'cause'),
#  ('is', 'to', 'cause', 'just'),
#  ('to', 'cause', 'just', 'such'),
#  ('cause', 'just', 'such', 'a'),
#  ('just', 'such', 'a', 're-evaluation'),
#  ('such', 'a', 're-evaluation', 'of'),
#  ('a', 're-evaluation', 'of', 'the'),
#  ('re-evaluation', 'of', 'the', 'program'),
#  ('of', 'the', 'program', 'about'),
#  ('the', 'program', 'about', 'to'),
#  ('program', 'about', 'to', 'be'),
#  ('about', 'to', 'be', '``'),
#  ('to', 'be', '``', 'explained'),
#  ('be', '``', 'explained', "''"),
#  ('``', 'explained', "''", '.'),
#  ('explained', "''", '.', 'Few'),
#  ("''", '.', 'Few', 'programs'),
#  ('.', 'Few', 'programs', 'ever'),
#  ('Few', 'programs', 'ever', 'needed'),
#  ('programs', 'ever', 'needed', 'it'),
#  ('ever', 'needed', 'it', 'more'),
#  ('needed', 'it', 'more', '.'),
#  ('it', 'more', '.', 'ELIZA'),
#  ('more', '.', 'ELIZA', "'s"),
#  ('.', 'ELIZA', "'s", 'key'),
#  ('ELIZA', "'s", 'key', 'method'),
#  ("'s", 'key', 'method', 'of'),
#  ('key', 'method', 'of', 'operation'),
#  ('method', 'of', 'operation', '('),
#  ('of', 'operation', '(', 'copied'),
#  ('operation', '(', 'copied', 'by'),
#  ('(', 'copied', 'by', 'chatbot'),
#  ('copied', 'by', 'chatbot', 'designers'),
#  ('by', 'chatbot', 'designers', 'ever'),
#  ('chatbot', 'designers', 'ever', 'since'),
#  ('designers', 'ever', 'since', ')'),
#  ('ever', 'since', ')', 'involves'),
#  ('since', ')', 'involves', 'the'),
#  (')', 'involves', 'the', 'recognition'),
#  ('involves', 'the', 'recognition', 'of'),
#  ('the', 'recognition', 'of', 'cue'),
#  ('recognition', 'of', 'cue', 'words'),
#  ('of', 'cue', 'words', 'or'),
#  ('cue', 'words', 'or', 'phrases'),
#  ('words', 'or', 'phrases', 'in'),
#  ('or', 'phrases', 'in', 'the'),
#  ('phrases', 'in', 'the', 'input'),
#  ('in', 'the', 'input', ','),
#  ('the', 'input', ',', 'and'),
#  ('input', ',', 'and', 'the'),
#  (',', 'and', 'the', 'output'),
#  ('and', 'the', 'output', 'of'),
#  ('the', 'output', 'of', 'corresponding'),
#  ('output', 'of', 'corresponding', 'pre-prepared'),
#  ('of', 'corresponding', 'pre-prepared', 'or'),
#  ('corresponding', 'pre-prepared', 'or', 'pre-programmed'),
#  ('pre-prepared', 'or', 'pre-programmed', 'responses'),
#  ('or', 'pre-programmed', 'responses', 'that'),
#  ('pre-programmed', 'responses', 'that', 'can'),
#  ('responses', 'that', 'can', 'move'),
#  ('that', 'can', 'move', 'the'),
#  ('can', 'move', 'the', 'conversation'),
#  ('move', 'the', 'conversation', 'forward'),
#  ('the', 'conversation', 'forward', 'in'),
#  ('conversation', 'forward', 'in', 'an'),
#  ('forward', 'in', 'an', 'apparently'),
#  ('in', 'an', 'apparently', 'meaningful'),
#  ('an', 'apparently', 'meaningful', 'way'),
#  ('apparently', 'meaningful', 'way', '('),
#  ('meaningful', 'way', '(', 'e.g'),
#  ('way', '(', 'e.g', '.'),
#  ('(', 'e.g', '.', 'by'),
#  ('e.g', '.', 'by', 'responding'),
#  ('.', 'by', 'responding', 'to'),
#  ('by', 'responding', 'to', 'any'),
#  ('responding', 'to', 'any', 'input'),
#  ('to', 'any', 'input', 'that'),
#  ('any', 'input', 'that', 'contains'),
#  ('input', 'that', 'contains', 'the'),
#  ('that', 'contains', 'the', 'word'),
#  ('contains', 'the', 'word', "'MOTHER"),
#  ('the', 'word', "'MOTHER", "'"),
#  ('word', "'MOTHER", "'", 'with'),
#  ("'MOTHER", "'", 'with', "'TELL"),
#  ("'", 'with', "'TELL", 'ME'),
#  ('with', "'TELL", 'ME', 'MORE'),
#  ("'TELL", 'ME', 'MORE', 'ABOUT'),
#  ('ME', 'MORE', 'ABOUT', 'YOUR'),
#  ('MORE', 'ABOUT', 'YOUR', 'FAMILY'),
#  ('ABOUT', 'YOUR', 'FAMILY', "'"),
#  ('YOUR', 'FAMILY', "'", ')'),
#  ('FAMILY', "'", ')', '.Thus'),
#  ("'", ')', '.Thus', 'an'),
#  (')', '.Thus', 'an', 'illusion'),
#  ('.Thus', 'an', 'illusion', 'of'),
#  ('an', 'illusion', 'of', 'understanding'),
#  ('illusion', 'of', 'understanding', 'is'),
#  ('of', 'understanding', 'is', 'generated'),
#  ('understanding', 'is', 'generated', ','),
#  ('is', 'generated', ',', 'even'),
#  ('generated', ',', 'even', 'though'),
#  (',', 'even', 'though', 'the'),
#  ('even', 'though', 'the', 'processing'),
#  ('though', 'the', 'processing', 'involved'),
#  ('the', 'processing', 'involved', 'has'),
#  ('processing', 'involved', 'has', 'been'),
#  ('involved', 'has', 'been', 'merely'),
#  ('has', 'been', 'merely', 'superficial'),
#  ('been', 'merely', 'superficial', '.'),
#  ('merely', 'superficial', '.', 'ELIZA'),
#  ('superficial', '.', 'ELIZA', 'showed'),
#  ('.', 'ELIZA', 'showed', 'that'),
#  ('ELIZA', 'showed', 'that', 'such'),
#  ('showed', 'that', 'such', 'an'),
#  ('that', 'such', 'an', 'illusion'),
#  ('such', 'an', 'illusion', 'is'),
#  ('an', 'illusion', 'is', 'surprisingly'),
#  ('illusion', 'is', 'surprisingly', 'easy'),
#  ('is', 'surprisingly', 'easy', 'to'),
#  ('surprisingly', 'easy', 'to', 'generate'),
#  ('easy', 'to', 'generate', ','),
#  ('to', 'generate', ',', 'because'),
#  ('generate', ',', 'because', 'human'),
#  (',', 'because', 'human', 'judges'),
#  ('because', 'human', 'judges', 'are'),
#  ('human', 'judges', 'are', 'so'),
#  ('judges', 'are', 'so', 'ready'),
#  ('are', 'so', 'ready', 'to'),
#  ('so', 'ready', 'to', 'give'),
#  ('ready', 'to', 'give', 'the'),
#  ('to', 'give', 'the', 'benefit'),
#  ('give', 'the', 'benefit', 'of'),
#  ('the', 'benefit', 'of', 'the'),
#  ('benefit', 'of', 'the', 'doubt'),
#  ('of', 'the', 'doubt', 'when'),
#  ('the', 'doubt', 'when', 'conversational'),
#  ('doubt', 'when', 'conversational', 'responses'),
#  ('when', 'conversational', 'responses', 'are'),
#  ('conversational', 'responses', 'are', 'capable'),
#  ('responses', 'are', 'capable', 'of'),
#  ('are', 'capable', 'of', 'being'),
#  ('capable', 'of', 'being', 'interpreted'),
#  ('of', 'being', 'interpreted', 'as'),
#  ('being', 'interpreted', 'as', '``'),
#  ('interpreted', 'as', '``', 'intelligent'),
#  ('as', '``', 'intelligent', "''"),
#  ('``', 'intelligent', "''", '.'),
#  ('intelligent', "''", '.', 'Interface'),
#  ("''", '.', 'Interface', 'designers'),
#  ('.', 'Interface', 'designers', 'have'),
#  ('Interface', 'designers', 'have', 'come'),
#  ('designers', 'have', 'come', 'to'),
#  ('have', 'come', 'to', 'appreciate'),
#  ('come', 'to', 'appreciate', 'that'),
#  ('to', 'appreciate', 'that', 'humans'),
#  ('appreciate', 'that', 'humans', "'"),
#  ('that', 'humans', "'", 'readiness'),
#  ('humans', "'", 'readiness', 'to'),
#  ("'", 'readiness', 'to', 'interpret'),
#  ('readiness', 'to', 'interpret', 'computer'),
#  ('to', 'interpret', 'computer', 'output'),
#  ('interpret', 'computer', 'output', 'as'),
#  ('computer', 'output', 'as', 'genuinely'),
#  ('output', 'as', 'genuinely', 'conversational—even'),
#  ('as', 'genuinely', 'conversational—even', 'when'),
#  ('genuinely', 'conversational—even', 'when', 'it'),
#  ('conversational—even', 'when', 'it', 'is'),
#  ('when', 'it', 'is', 'actually'),
#  ('it', 'is', 'actually', 'based'),
#  ('is', 'actually', 'based', 'on'),
#  ('actually', 'based', 'on', 'rather'),
#  ('based', 'on', 'rather', 'simple'),
#  ('on', 'rather', 'simple', 'pattern-matching—can'),
#  ('rather', 'simple', 'pattern-matching—can', 'be'),
#  ('simple', 'pattern-matching—can', 'be', 'exploited'),
#  ('pattern-matching—can', 'be', 'exploited', 'for'),
#  ('be', 'exploited', 'for', 'useful'),
#  ('exploited', 'for', 'useful', 'purposes'),
#  ('for', 'useful', 'purposes', '.'),
#  ('useful', 'purposes', '.', 'Most'),
#  ('purposes', '.', 'Most', 'people'),
#  ('.', 'Most', 'people', 'prefer'),
#  ('Most', 'people', 'prefer', 'to'),
#  ('people', 'prefer', 'to', 'engage'),
#  ('prefer', 'to', 'engage', 'with'),
#  ('to', 'engage', 'with', 'programs'),
#  ('engage', 'with', 'programs', 'that'),
#  ('with', 'programs', 'that', 'are'),
#  ('programs', 'that', 'are', 'human-like'),
#  ('that', 'are', 'human-like', ','),
#  ('are', 'human-like', ',', 'and'),
#  ('human-like', ',', 'and', 'this'),
#  (',', 'and', 'this', 'gives'),
#  ('and', 'this', 'gives', 'chatbot-style'),
#  ('this', 'gives', 'chatbot-style', 'techniques'),
#  ('gives', 'chatbot-style', 'techniques', 'a'),
#  ('chatbot-style', 'techniques', 'a', 'potentially'),
#  ('techniques', 'a', 'potentially', 'useful'),
#  ('a', 'potentially', 'useful', 'role'),
#  ('potentially', 'useful', 'role', 'in'),
#  ('useful', 'role', 'in', 'interactive'),
#  ('role', 'in', 'interactive', 'systems'),
#  ('in', 'interactive', 'systems', 'that'),
#  ('interactive', 'systems', 'that', 'need'),
#  ('systems', 'that', 'need', 'to'),
#  ('that', 'need', 'to', 'elicit'),
#  ('need', 'to', 'elicit', 'information'),
#  ('to', 'elicit', 'information', 'from'),
#  ('elicit', 'information', 'from', 'users'),
#  ('information', 'from', 'users', ','),
#  ('from', 'users', ',', 'as'),
#  ('users', ',', 'as', 'long'),
#  (',', 'as', 'long', 'as'),
#  ('as', 'long', 'as', 'that'),
#  ('long', 'as', 'that', 'information'),
#  ('as', 'that', 'information', 'is'),
#  ('that', 'information', 'is', 'relatively'),
#  ('information', 'is', 'relatively', 'straightforward'),
#  ('is', 'relatively', 'straightforward', 'and'),
#  ('relatively', 'straightforward', 'and', 'falls'),
#  ('straightforward', 'and', 'falls', 'into'),
#  ('and', 'falls', 'into', 'predictable'),
#  ('falls', 'into', 'predictable', 'categories'),
#  ('into', 'predictable', 'categories', '.'),
#  ('predictable', 'categories', '.', 'Thus'),
#  ('categories', '.', 'Thus', ','),
#  ('.', 'Thus', ',', 'for'),
#  ('Thus', ',', 'for', 'example'),
#  (',', 'for', 'example', ','),
#  ('for', 'example', ',', 'online'),
#  ('example', ',', 'online', 'help'),
#  (',', 'online', 'help', 'systems'),
#  ('online', 'help', 'systems', 'can'),
#  ('help', 'systems', 'can', 'usefully'),
#  ('systems', 'can', 'usefully', 'employ'),
#  ('can', 'usefully', 'employ', 'chatbot'),
#  ('usefully', 'employ', 'chatbot', 'techniques'),
#  ('employ', 'chatbot', 'techniques', 'to'),
#  ('chatbot', 'techniques', 'to', 'identify'),
#  ('techniques', 'to', 'identify', 'the'),
#  ('to', 'identify', 'the', 'area'),
#  ('identify', 'the', 'area', 'of'),
#  ('the', 'area', 'of', 'help'),
#  ('area', 'of', 'help', 'that'),
#  ('of', 'help', 'that', 'users'),
#  ('help', 'that', 'users', 'require'),
#  ('that', 'users', 'require', ','),
#  ('users', 'require', ',', 'potentially'),
#  ('require', ',', 'potentially', 'providing'),
#  (',', 'potentially', 'providing', 'a'),
#  ('potentially', 'providing', 'a', '``'),
#  ('providing', 'a', '``', 'friendlier'),
#  ('a', '``', 'friendlier', "''"),
#  ('``', 'friendlier', "''", 'interface'),
#  ('friendlier', "''", 'interface', 'than'),
#  ("''", 'interface', 'than', 'a'),
#  ('interface', 'than', 'a', 'more'),
#  ('than', 'a', 'more', 'formal'),
#  ('a', 'more', 'formal', 'search'),
#  ('more', 'formal', 'search', 'or'),
#  ('formal', 'search', 'or', 'menu'),
#  ('search', 'or', 'menu', 'system'),
#  ('or', 'menu', 'system', '.'),
#  ('menu', 'system', '.', 'This'),
#  ('system', '.', 'This', 'sort'),
#  ('.', 'This', 'sort', 'of'),
#  ('This', 'sort', 'of', 'usage'),
#  ('sort', 'of', 'usage', 'holds'),
#  ('of', 'usage', 'holds', 'the'),
#  ('usage', 'holds', 'the', 'prospect'),
#  ('holds', 'the', 'prospect', 'of'),
#  ('the', 'prospect', 'of', 'moving'),
#  ('prospect', 'of', 'moving', 'chatbot'),
#  ('of', 'moving', 'chatbot', 'technology'),
#  ('moving', 'chatbot', 'technology', 'from'),
#  ('chatbot', 'technology', 'from', 'Weizenbaum'),
#  ('technology', 'from', 'Weizenbaum', "'s"),
#  ('from', 'Weizenbaum', "'s", '``'),
#  ('Weizenbaum', "'s", '``', 'shelf'),
#  ("'s", '``', 'shelf', '...'),
#  ('``', 'shelf', '...', 'reserved'),
#  ('shelf', '...', 'reserved', 'for'),
#  ('...', 'reserved', 'for', 'curios'),
#  ('reserved', 'for', 'curios', "''"),
#  ('for', 'curios', "''", 'to'),
#  ('curios', "''", 'to', 'that'),
#  ("''", 'to', 'that', 'marked'),
#  ('to', 'that', 'marked', '``'),
#  ('that', 'marked', '``', 'genuinely'),
#  ('marked', '``', 'genuinely', 'useful'),
#  ('``', 'genuinely', 'useful', 'computational'),
#  ('genuinely', 'useful', 'computational', 'methods'),
#  ('useful', 'computational', 'methods', "''"),
#  ('computational', 'methods', "''", '.'),
#  ('methods', "''", '.', 'Development'),
#  ("''", '.', 'Development', 'The'),
#  ('.', 'Development', 'The', 'classic'),
#  ('Development', 'The', 'classic', 'historic'),
#  ('The', 'classic', 'historic', 'early'),
#  ('classic', 'historic', 'early', 'chatbots'),
#  ('historic', 'early', 'chatbots', 'are'),
#  ('early', 'chatbots', 'are', 'ELIZA'),
#  ('chatbots', 'are', 'ELIZA', '('),
#  ('are', 'ELIZA', '(', '1966'),
#  ('ELIZA', '(', '1966', ')'),
#  ('(', '1966', ')', 'and'),
#  ('1966', ')', 'and', 'PARRY'),
#  (')', 'and', 'PARRY', '('),
#  ('and', 'PARRY', '(', '1972'),
#  ('PARRY', '(', '1972', ')'),
#  ('(', '1972', ')', '.More'),
#  ('1972', ')', '.More', 'recent'),
#  (')', '.More', 'recent', 'notable'),
#  ('.More', 'recent', 'notable', 'programs'),
#  ('recent', 'notable', 'programs', 'include'),
#  ('notable', 'programs', 'include', 'A.L.I.C.E.'),
#  ('programs', 'include', 'A.L.I.C.E.', ','),
#  ('include', 'A.L.I.C.E.', ',', 'Jabberwacky'),
#  ('A.L.I.C.E.', ',', 'Jabberwacky', 'and'),
#  (',', 'Jabberwacky', 'and', 'D.U.D.E'),
#  ('Jabberwacky', 'and', 'D.U.D.E', '('),
#  ('and', 'D.U.D.E', '(', 'Agence'),
#  ('D.U.D.E', '(', 'Agence', 'Nationale'),
#  ('(', 'Agence', 'Nationale', 'de'),
#  ('Agence', 'Nationale', 'de', 'la'),
#  ('Nationale', 'de', 'la', 'Recherche'),
#  ('de', 'la', 'Recherche', 'and'),
#  ('la', 'Recherche', 'and', 'CNRS'),
#  ('Recherche', 'and', 'CNRS', '2006'),
#  ('and', 'CNRS', '2006', ')'),
#  ('CNRS', '2006', ')', '.'),
#  ('2006', ')', '.', 'While'),
#  (')', '.', 'While', 'ELIZA'),
#  ('.', 'While', 'ELIZA', 'and'),
#  ('While', 'ELIZA', 'and', 'PARRY'),
#  ('ELIZA', 'and', 'PARRY', 'were'),
#  ('and', 'PARRY', 'were', 'used'),
#  ('PARRY', 'were', 'used', 'exclusively'),
#  ('were', 'used', 'exclusively', 'to'),
#  ('used', 'exclusively', 'to', 'simulate'),
#  ('exclusively', 'to', 'simulate', 'typed'),
#  ('to', 'simulate', 'typed', 'conversation'),
#  ('simulate', 'typed', 'conversation', ','),
#  ('typed', 'conversation', ',', 'many'),
#  ('conversation', ',', 'many', 'chatbots'),
#  (',', 'many', 'chatbots', 'now'),
#  ('many', 'chatbots', 'now', 'include'),
#  ('chatbots', 'now', 'include', 'functional'),
#  ('now', 'include', 'functional', 'features'),
#  ('include', 'functional', 'features', 'such'),
#  ('functional', 'features', 'such', 'as'),
#  ('features', 'such', 'as', 'games'),
#  ('such', 'as', 'games', 'and'),
#  ('as', 'games', 'and', 'web'),
#  ('games', 'and', 'web', 'searching'),
#  ('and', 'web', 'searching', 'abilities'),
#  ('web', 'searching', 'abilities', '.'),
#  ('searching', 'abilities', '.', 'In'),
#  ('abilities', '.', 'In', '1984'),
#  ('.', 'In', '1984', ','),
#  ('In', '1984', ',', 'a'),
#  ('1984', ',', 'a', 'book'),
#  (',', 'a', 'book', 'called'),
#  ('a', 'book', 'called', 'The'),
#  ('book', 'called', 'The', 'Policeman'),
#  ('called', 'The', 'Policeman', "'s"),
#  ('The', 'Policeman', "'s", 'Beard'),
#  ('Policeman', "'s", 'Beard', 'is'),
#  ("'s", 'Beard', 'is', 'Half'),
#  ('Beard', 'is', 'Half', 'Constructed'),
#  ('is', 'Half', 'Constructed', 'was'),
#  ('Half', 'Constructed', 'was', 'published'),
#  ('Constructed', 'was', 'published', ','),
#  ('was', 'published', ',', 'allegedly'),
#  ('published', ',', 'allegedly', 'written'),
#  (',', 'allegedly', 'written', 'by'),
#  ('allegedly', 'written', 'by', 'the'),
#  ('written', 'by', 'the', 'chatbot'),
#  ('by', 'the', 'chatbot', 'Racter'),
#  ('the', 'chatbot', 'Racter', '('),
#  ('chatbot', 'Racter', '(', 'though'),
#  ('Racter', '(', 'though', 'the'),
#  ('(', 'though', 'the', 'program'),
#  ('though', 'the', 'program', 'as'),
#  ('the', 'program', 'as', 'released'),
#  ('program', 'as', 'released', 'would'),
#  ('as', 'released', 'would', 'not'),
#  ('released', 'would', 'not', 'have'),
#  ('would', 'not', 'have', 'been'),
#  ('not', 'have', 'been', 'capable'),
#  ('have', 'been', 'capable', 'of'),
#  ('been', 'capable', 'of', 'doing'),
#  ('capable', 'of', 'doing', 'so'),
#  ('of', 'doing', 'so', ')'),
#  ('doing', 'so', ')', '.'),
#  ('so', ')', '.', 'One'),
#  (')', '.', 'One', 'pertinent'),
#  ('.', 'One', 'pertinent', 'field'),
#  ('One', 'pertinent', 'field', 'of'),
#  ('pertinent', 'field', 'of', 'AI'),
#  ('field', 'of', 'AI', 'research'),
#  ('of', 'AI', 'research', 'is'),
#  ('AI', 'research', 'is', 'natural'),
#  ('research', 'is', 'natural', 'language'),
#  ('is', 'natural', 'language', 'processing'),
#  ('natural', 'language', 'processing', '.'),
#  ('language', 'processing', '.', 'Usually'),
#  ('processing', '.', 'Usually', ','),
#  ('.', 'Usually', ',', 'weak'),
#  ('Usually', ',', 'weak', 'AI'),
#  (',', 'weak', 'AI', 'fields'),
#  ('weak', 'AI', 'fields', 'employ'),
#  ('AI', 'fields', 'employ', 'specialized'),
#  ('fields', 'employ', 'specialized', 'software'),
#  ('employ', 'specialized', 'software', 'or'),
#  ('specialized', 'software', 'or', 'programming'),
#  ('software', 'or', 'programming', 'languages'),
#  ('or', 'programming', 'languages', 'created'),
#  ('programming', 'languages', 'created', 'specifically'),
#  ('languages', 'created', 'specifically', 'for'),
#  ('created', 'specifically', 'for', 'the'),
#  ('specifically', 'for', 'the', 'narrow'),
#  ('for', 'the', 'narrow', 'function'),
#  ('the', 'narrow', 'function', 'required'),
#  ('narrow', 'function', 'required', '.'),
#  ('function', 'required', '.', 'For'),
#  ('required', '.', 'For', 'example'),
#  ('.', 'For', 'example', ','),
#  ('For', 'example', ',', 'A.L.I.C.E'),
#  ('example', ',', 'A.L.I.C.E', '.'),
#  (',', 'A.L.I.C.E', '.', 'uses'),
#  ('A.L.I.C.E', '.', 'uses', 'a'),
#  ('.', 'uses', 'a', 'markup'),
#  ('uses', 'a', 'markup', 'language'),
#  ('a', 'markup', 'language', 'called'),
#  ('markup', 'language', 'called', 'AIML'),
#  ('language', 'called', 'AIML', ','),
#  ('called', 'AIML', ',', 'which'),
#  ('AIML', ',', 'which', 'is'),
#  (',', 'which', 'is', 'specific'),
#  ('which', 'is', 'specific', 'to'),
#  ('is', 'specific', 'to', 'its'),
#  ('specific', 'to', 'its', 'function'),
#  ('to', 'its', 'function', 'as'),
#  ('its', 'function', 'as', 'a'),
#  ('function', 'as', 'a', 'conversational'),
#  ('as', 'a', 'conversational', 'agent'),
#  ('a', 'conversational', 'agent', ','),
#  ('conversational', 'agent', ',', 'and'),
#  ('agent', ',', 'and', 'has'),
#  (',', 'and', 'has', 'since'),
#  ('and', 'has', 'since', 'been'),
#  ('has', 'since', 'been', 'adopted'),
#  ('since', 'been', 'adopted', 'by'),
#  ('been', 'adopted', 'by', 'various'),
#  ('adopted', 'by', 'various', 'other'),
#  ('by', 'various', 'other', 'developers'),
#  ('various', 'other', 'developers', 'of'),
#  ('other', 'developers', 'of', ','),
#  ('developers', 'of', ',', 'so'),
#  ('of', ',', 'so', 'called'),
#  (',', 'so', 'called', ','),
#  ('so', 'called', ',', 'Alicebots'),
#  ('called', ',', 'Alicebots', '.'),
#  (',', 'Alicebots', '.', 'Nevertheless'),
#  ('Alicebots', '.', 'Nevertheless', ','),
#  ('.', 'Nevertheless', ',', 'A.L.I.C.E'),
#  ('Nevertheless', ',', 'A.L.I.C.E', '.'),
#  (',', 'A.L.I.C.E', '.', 'is'),
#  ('A.L.I.C.E', '.', 'is', 'still'),
#  ('.', 'is', 'still', 'purely'),
#  ('is', 'still', 'purely', 'based'),
#  ('still', 'purely', 'based', 'on'),
#  ('purely', 'based', 'on', 'pattern'),
#  ('based', 'on', 'pattern', 'matching'),
#  ('on', 'pattern', 'matching', 'techniques'),
#  ('pattern', 'matching', 'techniques', 'without'),
#  ('matching', 'techniques', 'without', 'any'),
#  ('techniques', 'without', 'any', 'reasoning'),
#  ('without', 'any', 'reasoning', 'capabilities'),
#  ('any', 'reasoning', 'capabilities', ','),
#  ('reasoning', 'capabilities', ',', 'the'),
#  ('capabilities', ',', 'the', 'same'),
#  (',', 'the', 'same', 'technique'),
#  ('the', 'same', 'technique', 'ELIZA'),
#  ('same', 'technique', 'ELIZA', 'was'),
#  ('technique', 'ELIZA', 'was', 'using'),
#  ('ELIZA', 'was', 'using', 'back'),
#  ('was', 'using', 'back', 'in'),
#  ('using', 'back', 'in', '1966'),
#  ('back', 'in', '1966', '.'),
#  ('in', '1966', '.', 'This'),
#  ('1966', '.', 'This', 'is'),
#  ('.', 'This', 'is', 'not'),
#  ('This', 'is', 'not', 'strong'),
#  ('is', 'not', 'strong', 'AI'),
#  ('not', 'strong', 'AI', ','),
#  ('strong', 'AI', ',', 'which'),
#  ('AI', ',', 'which', 'would'),
#  (',', 'which', 'would', 'require'),
#  ('which', 'would', 'require', 'sapience'),
#  ('would', 'require', 'sapience', 'and'),
#  ('require', 'sapience', 'and', 'logical'),
#  ('sapience', 'and', 'logical', 'reasoning'),
#  ('and', 'logical', 'reasoning', 'abilities'),
#  ('logical', 'reasoning', 'abilities', '.'),
#  ('reasoning', 'abilities', '.', 'Jabberwacky'),
#  ('abilities', '.', 'Jabberwacky', 'learns'),
#  ('.', 'Jabberwacky', 'learns', 'new'),
#  ...]

# %%
from nltk.stem import PorterStemmer
pst=PorterStemmer()
pst.stem("restriction")
words_to_stem=["give","giving","given","gave"]
for word in words_to_stem:
    print(word+":"+pst.stem(word))
# Out:
# give:give
# giving:give
# given:given
# gave:gave

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
word_lem=WordNetLemmatizer()
word_lem.lemmatize("gone")
# Out:
# [nltk_data] Error loading wordnet: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# 'gone'

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stopwords.words("english")
len(stopwords.words("english"))
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# 179

# %%
fdist_top5
# Out:
# [(',', 125),
#  ('the', 83),
#  ('.', 71),
#  ('a', 55),
#  ('to', 48),
#  ('of', 48),
#  ('and', 43),
#  ('in', 33),
#  ('as', 30),
#  ('chatbot', 27)]

# %%
import re
punctuation=re.compile(r'[-.?!,:;()|0-9]')
post_punctuation=[]
for words in AI_tokens:
    word=punctuation.sub("",words)
if len(word)>0:
    post_punctuation.append(word)
post_punctuation 
len(post_punctuation)
# Out:
# 0

# %%
nltk.download('averaged_perceptron_tagger')
#pos
sent="Restriction enzymes are one of the everyday tools used in molecular biology."
sent_toke=word_tokenize(sent)
for token in sent_toke:
    print(nltk.pos_tag([token]))
# Out:
# [nltk_data] Error loading averaged_perceptron_tagger: <urlopen error
# [nltk_data]     [WinError 10060] A connection attempt failed because
# [nltk_data]     the connected party did not properly respond after a
# [nltk_data]     period of time, or established connection failed
# [nltk_data]     because connected host has failed to respond>
# [('Restriction', 'NN')]
# [('enzymes', 'NNS')]
# [('are', 'VBP')]
# [('one', 'CD')]
# [('of', 'IN')]
# [('the', 'DT')]
# [('everyday', 'NN')]
# [('tools', 'NNS')]
# [('used', 'VBN')]
# [('in', 'IN')]
# [('molecular', 'NN')]
# [('biology', 'NN')]
# [('.', '.')]

# %%
from nltk import ne_chunk
nltk.download('maxent_ne_chunker')
ne_sent="The US President stays in the White House"
nltk.download('words')
ne_token=word_tokenize(ne_sent)
ne_tags=nltk.pos_tag(ne_token)
ne_ner=ne_chunk(ne_tags)
print(ne_ner)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\GAYATHRI\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\GAYATHRI\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# (S
#   The/DT
#   (ORGANIZATION US/NNP)
#   President/NNP
#   stays/VBZ
#   in/IN
#   the/DT
#   (FACILITY White/NNP House/NNP))

# %%
new="The big cat are the little mouse who was after fresh cheese"
new_toke=nltk.pos_tag(word_tokenize(new))
new_toke
# Out:
# [('The', 'DT'),
#  ('big', 'JJ'),
#  ('cat', 'NN'),
#  ('are', 'VBP'),
#  ('the', 'DT'),
#  ('little', 'JJ'),
#  ('mouse', 'NN'),
#  ('who', 'WP'),
#  ('was', 'VBD'),
#  ('after', 'IN'),
#  ('fresh', 'JJ'),
#  ('cheese', 'NN')]

# %%
import nltk
import warnings
warnings.filterwarnings("ignore")
# nltk.download() # for downloading packages
import numpy as np
import random
import string # to process standard python strings

# %% [markdown]
# # Reading in the corpus
# For our example,we will be using the Wikipedia page for chatbots as our corpus. Copy the contents from the page and place it in a text file named ‘chatbot.txt’. However, you can use any corpus of your choice.

# %%
f=open(r'C:\Users\GAYATHRI\OneDrive\Documents\SRET-I YR- MSC\TERM III\Machine Learning\FinalProject\chatbot.txt','r',errors = 'ignore')
raw=f.read()
raw=raw.lower()# converts to lowercase
#nltk.download('punkt') # first-time use only
#nltk.download('wordnet') # first-time use only

# %% [markdown]
# The main issue with text data is that it is all in text format (strings). However, the Machine learning algorithms need some sort of numerical feature vector in order to perform the task. So before we start with any NLP project we need to pre-process it to make it ideal for working. Basic text pre-processing includes:
#
# Converting the entire text into uppercase or lowercase, so that the algorithm does not treat the same words in different cases as different
#
# Tokenization: Tokenization is just the term used to describe the process of converting the normal text strings into a list of tokens i.e words that we actually want. Sentence tokenizer can be used to find the list of sentences and Word tokenizer can be used to find the list of words in strings.
#
# The NLTK data package includes a pre-trained Punkt tokenizer for English.
#
# Removing Noise i.e everything that isn’t in a standard number or letter.
# Removing the Stop words. Sometimes, some extremely common words which would appear to be of little value in helping select documents matching a user need are excluded from the vocabulary entirely. These words are called stop words
# Stemming: Stemming is the process of reducing inflected (or sometimes derived) words to their stem, base or root form — generally a written word form. Example if we were to stem the following words: “Stems”, “Stemming”, “Stemmed”, “and Stemtization”, the result would be a single word “stem”.
# Lemmatization: A slight variant of stemming is lemmatization. The major difference between these is, that, stemming can often create non-existent words, whereas lemmas are actual words. So, your root stem, meaning the word you end up with, is not something you can just look up in a dictionary, but you can look up a lemma. Examples of Lemmatization are that “run” is a base form for words like “running” or “ran” or that the word “better” and “good” are in the same lemma so they are considered the same.
#
# # Tokenisation

# %%
sent_tokens = nltk.sent_tokenize(raw)# converts to list of sentences
word_tokens = nltk.word_tokenize(raw)# converts to list of words
sent_tokens[:2]
word_tokens[:5]
# Out:
# ['a', 'chatbot', '(', 'also', 'known']

# %% [markdown]
# # Preprocessing
# We shall now define a function called LemTokens which will take as input the tokens and return normalized tokens.

# %%
import nltk
from nltk.stem import WordNetLemmatizer

# Define a function to perform lemmatization on a list of tokens
def LemTokens(tokens):
    lemmer = WordNetLemmatizer()
    return [lemmer.lemmatize(token) for token in tokens]

# Example text
text = "Hello, this is an example sentence."

# Tokenize the text, remove punctuation, and perform lemmatization
tokens = nltk.word_tokenize(text.lower().translate(remove_punct_dict))
lemmatized_tokens = LemTokens(tokens)

print(lemmatized_tokens)
# Out:
# ['hello', 'this', 'is', 'an', 'example', 'sentence']

# %% [markdown]
# # Keyword matching
# Next, we shall define a function for a greeting by the bot i.e if a user’s input is a greeting, the bot shall return a greeting response.ELIZA uses a simple keyword matching for greetings. We will utilize the same concept here.

# %%
GREETING_INPUTS = ("hello", "hi", "greetings", "sup", "what's up","hey","hi buddy")
GREETING_RESPONSES = ["hi", "hey", "*nods*", "hi there", "hello", "I am glad! You are talking to me","hello buddy"]
GREETING_INPUTS = ("hello", "hi", "greetings", "sup", "what's up","hey",)
GREETING_RESPONSES = ["hi", "hey", "*nods*", "hi there", "hello", "I am glad! You are talking to me"]
def greeting(sentence):
 
    for word in sentence.split():
        if word.lower() in GREETING_INPUTS:
            return random.choice(GREETING_RESPONSES)
Welcome_input=("i need project")
Welcome_response=["how can you help you buddy","ddfgdfgdf"]

# %% [markdown]
# # Generating Response
# # Bag of Words
# After the initial preprocessing phase, we need to transform text into a meaningful vector (or array) of numbers. The bag-of-words is a representation of text that describes the occurrence of words within a document. It involves two things:
#
# A vocabulary of known words.
#
# A measure of the presence of known words.
#
# Why is it is called a “bag” of words? That is because any information about the order or structure of words in the document is discarded and the model is only concerned with whether the known words occur in the document, not where they occur in the document.
#
# The intuition behind the Bag of Words is that documents are similar if they have similar content. Also, we can learn something about the meaning of the document from its content alone.
#
# For example, if our dictionary contains the words {Learning, is, the, not, great}, and we want to vectorize the text “Learning is great”, we would have the following vector: (1, 1, 0, 0, 1).
#
# # TF-IDF Approach
# A problem with the Bag of Words approach is that highly frequent words start to dominate in the document (e.g. larger score), but may not contain as much “informational content”. Also, it will give more weight to longer documents than shorter documents.
#
# One approach is to rescale the frequency of words by how often they appear in all documents so that the scores for frequent words like “the” that are also frequent across all documents are penalized. This approach to scoring is called Term Frequency-Inverse Document Frequency, or TF-IDF for short, where:
#
# Term Frequency: is a scoring of the frequency of the word in the current document.
#
#     TF = (Number of times term t appears in a document)/(Number of terms in the document)
# Inverse Document Frequency: is a scoring of how rare the word is across documents.
#
# IDF = 1+log(N/n), where, N is the number of documents and n is the number of documents a term t has appeared in.
# # Cosine Similarity
# Tf-idf weight is a weight often used in information retrieval and text mining. This weight is a statistical measure used to evaluate how important a word is to a document in a collection or corpus
#
# Cosine Similarity (d1, d2) =  Dot product(d1, d2) / ||d1|| * ||d2||
# where d1,d2 are two non zero vectors.
#
# To generate a response from our bot for input questions, the concept of document similarity will be used. We define a function response which searches the user’s utterance for one or more known keywords and returns one of several possible responses. If it doesn’t find the input matching any of the keywords, it returns a response:” I am sorry! I don’t understand you”

# %%
# Generating response
def response(user_response):
    robo_response=''
    sent_tokens.append(user_response)
    TfidfVec = TfidfVectorizer(tokenizer=LemNormalize, stop_words='english')
    tfidf = TfidfVec.fit_transform(sent_tokens)
    vals = cosine_similarity(tfidf[-1], tfidf)
    idx=vals.argsort()[0][-2]
    flat = vals.flatten()
    flat.sort()
    req_tfidf = flat[-2]

# %%
def generate_response(req_tfidf, robo_response, sent_tokens, idx):
    if req_tfidf == 0:
        robo_response = robo_response + "I am sorry! I don't understand you"
        return robo_response
    else:
        robo_response = robo_response + sent_tokens[idx]
        return robo_response

# %%
flag=True
print("ROBO: My name is Robo. I will answer your queries about Chatbots. If you want to exit, type Bye!")
while(flag==True):
    user_response = input()
    user_response=user_response.lower()
    if(user_response!='bye'):
        if(user_response=='thanks' or user_response=='thank you' ):
            flag=False
            print("ROBO: You are welcome..")
        else:
            if(greeting(user_response)!=None):
                print("ROBO: "+greeting(user_response))
            else:
                print("ROBO: ",end="")
                print(response(user_response))
                sent_tokens.remove(user_response)
    else:
        flag=False
        print("ROBO: Bye! take care..")
# Out:
# ROBO: My name is Robo. I will answer your queries about Chatbots. If you want to exit, type Bye!
# hi
# ROBO: hello
# hey
# ROBO: hello
# bye
# ROBO: Bye! take care..
